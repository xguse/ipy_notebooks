# %%
from __future__ import print_function, division

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
xls_path = "/home/gus/MEGAsync/zim/main/BCH/Projects/Jodie_families/varseq_export/CHB435.xlsx"

# %%
chb435 = pd.read_excel(io=xls_path, sheetname="Variants-FilterChainInput-CHB", header=[0,1], skiprows=None, skip_footer=0, 
                       index_col=None, parse_cols=None, parse_dates=False, date_parser=None, 
                       na_values=None, thousands=None, convert_float=True, 
                       has_index_names=None, converters=None, engine=None)
# Out:
# /home/gus/anaconda2/envs/stack2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:3066: PerformanceWarning: indexing past lexsort depth may impact performance.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
chb435.T.head()
# Out:
#                                          1:897454 1:978604     1:1247579  \
# Variant Sites    Chr:Pos
# Variant Sites    Ref/Alt                      -/C     CT/-  -/GGGGG/GGGG
#                  Identifier                   NaN      NaN           NaN
# Proband (CHB435) Allelic Depths (AD)          NaN    59,49           NaN
#                  Read Depths (DP)             NaN      108           NaN
#                  Genotype Qualities (GQ)      NaN       99           NaN
#
#                                          1:1260010 1:1276974 1:1289368  \
# Variant Sites    Chr:Pos
# Variant Sites    Ref/Alt                       -/C    -/ACAC      TG/-
#                  Identifier                    NaN       NaN       NaN
# Proband (CHB435) Allelic Depths (AD)         47,35     0,134     0,128
#                  Read Depths (DP)               82       134       128
#                  Genotype Qualities (GQ)        99        99        99
#
# ...
