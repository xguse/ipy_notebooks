# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_context("talk")

# %%
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

r = robjects.r

nsn = importr("NanoStringNorm")
egr = importr("edgeR")

py = pandas2ri.ri2py

# %%
cell_type = 'CD14'

# %% [markdown]
# # Read in RCC data

# %%
base_path = u'/home/gus/MEGAsync/zim/main/BCH/Projects/James/Nanostring_pipeline/OKT3/data/compare_ours_to_existing/cd14'

our_rcc_path = base_path+u"/ours"
thr_rcc_path = base_path+u"/theirs"

# %%
our_data = py(r(u"""read.markup.RCC(rcc.path="{PATH}")""".format(PATH=our_rcc_path)).rx2('x'))
thr_data = py(r(u"""read.markup.RCC(rcc.path="{PATH}")""".format(PATH=thr_rcc_path)).rx2('x'))

# %%
our_data.shape
# Out:
# (608, 9)

# %%
thr_data.shape
# Out:
# (540, 13)

# %%
our_data.head()
# Out:
#     CodeClass      Name    Accession  BWH006_CD14_w0_04  BWH008_CD14_w0_09  \
# 1  Endogenous       VTN  NM_000638.3                  1                  0
# 2  Endogenous  HLA-DQB1  NM_002123.3                  8                  8
# 3  Endogenous       KIT  NM_000222.2                  2                  0
# 4  Endogenous      LAG3  NM_002286.5                  2                  7
# 5  Endogenous     SOCS3  NM_003955.3                 11                 23
#
#    MGH001_CD14_w0_07  MGH002_CD14_w0_05  MGH004_CD14_w0_09  MGH007_CD14_w0_10
# 1                  4                  0                  2                  1
# 2                  2                 11                  0                  2
# 3                  3                  1                  3                  2
# 4                  3                  1                  1                  0
# 5                387                 15                  7                206

# %%
our_genes = set(our_data.Name.unique())
thr_genes = set(thr_data.Name.unique())

# %%
len(our_genes.intersection(thr_genes))
# Out:
# 520

# %% [markdown]
# ## Join tables by gene names
#
# - We will only deal with the genes that are in commen between the tables from now on
# - thats 520 including the pos/neg controls etc.

# %%
cmb_data = pd.merge(left=our_data, right=thr_data,
                    how='inner', on="Name",
                    left_on=None, right_on=None,
                    left_index=False, right_index=False,
                    sort=False, suffixes=('_OUR', '_THR'), copy=True, indicator=False)

cmb_data.index = cmb_data.Name.values
cmb_data = cmb_data.drop(labels=['Name'],axis=1)
cmb_data.head()
# Out:
#          CodeClass_OUR Accession_OUR  BWH006_CD14_w0_04  BWH008_CD14_w0_09  \
# VTN         Endogenous   NM_000638.3                  1                  0
# HLA-DQB1    Endogenous   NM_002123.3                  8                  8
# KIT         Endogenous   NM_000222.2                  2                  0
# SOCS3       Endogenous   NM_003955.3                 11                 23
# TCF7        Endogenous   NM_003202.2                  0                  1
#
#           MGH001_CD14_w0_07  MGH002_CD14_w0_05  MGH004_CD14_w0_09  \
# VTN                       4                  0                  2
# HLA-DQB1                  2                 11                  0
# KIT                       3                  1                  3
# SOCS3                   387                 15                  7
# TCF7                      3                  1                  0
#
#           MGH007_CD14_w0_10 CodeClass_THR Accession_THR  GSM973583  GSM973584  \
# VTN                       1    Endogenous   NM_000638.3         20         44
# HLA-DQB1                  2    Endogenous   NM_002123.3        790       4686
# KIT                       2    Endogenous   NM_000222.1         42         43
# SOCS3                   206    Endogenous   NM_003955.3       4265       8859
# TCF7                      1    Endogenous   NM_003202.2         44         81
#
#           GSM973585  GSM973586  GSM973587  GSM973588  GSM973589  GSM973590  \
# VTN              36         27         22         23          9         22
# HLA-DQB1       4274         27         11         16       1778       2381
# KIT              32         36         35         27         22         37
# SOCS3          6741       5401       4226       2073       3250       6298
# TCF7             59        138         38         44         30         58
#
#           GSM973591  GSM973592
# VTN              27         20
# HLA-DQB1       8212       2225
# KIT              29         31
# SOCS3          3883       4945
# TCF7             62         33

# %%
code_class_missmatch = cmb_data.CodeClass_OUR != cmb_data.CodeClass_THR
sum(code_class_missmatch)
# Out:
# 15

# %% [markdown]
# 15 rows have CodeClass designations that don't match up...

# %%
cmb_data[code_class_missmatch][['CodeClass_OUR','CodeClass_THR']]
# Out:
#        CodeClass_OUR CodeClass_THR
# EEF1G   Housekeeping    Endogenous
# TUBB    Housekeeping    Endogenous
# TBP     Housekeeping    Endogenous
# POLR2A  Housekeeping    Endogenous
# GUSB    Housekeeping    Endogenous
# HPRT1   Housekeeping    Endogenous
# GAPDH   Housekeeping    Endogenous
# SDHA    Housekeeping    Endogenous
# OAZ1    Housekeeping    Endogenous
# PPIA    Housekeeping    Endogenous
# G6PD    Housekeeping    Endogenous
# RPL19   Housekeeping    Endogenous
# POLR1B  Housekeeping    Endogenous
# ABCF1   Housekeeping    Endogenous
# ALAS1   Housekeeping    Endogenous

# %% [markdown]
# Looks like its not too big a deal.  They just added some genes as housekeepers.

# %% [markdown]
# ## OK lets get rid of CodeClass and Accession Columns and write to file

# %%
cmb_data_extra_cols = cmb_data[['CodeClass_OUR','Accession_OUR','CodeClass_THR','Accession_THR']].copy()

cmb_data_for_nsn = cmb_data.drop(labels=['CodeClass_THR','Accession_THR'],axis=1)
cmb_data = cmb_data.drop(labels=['CodeClass_OUR','Accession_OUR','CodeClass_THR','Accession_THR'],axis=1)

# %%
cmb_data_for_nsn
# Out:
#               BWH006_CD14_w0_04  BWH008_CD14_w0_09  MGH001_CD14_w0_07  \
# VTN                           1                  0                  4
# HLA-DQB1                      8                  8                  2
# KIT                           2                  0                  3
# SOCS3                        11                 23                387
# TCF7                          0                  1                  3
# IKBKB                         5                  5                 22
# ITGA6                         1                  3                 10
# CXCR4                        16                 20                490
# NFKBIZ                       13                 27                113
# MAPK14                       14                 19                162
# IL32                        538               2073              13558
# CFB                           1                  3                  3
# CXCL1                         0                  1                  8
# CEACAM1                       0                  2                  4
# C8A                           0                  2                  3
# CFP                          13                 23                186
# LILRA5                       13                 33                391
# IL10RA                       14                 43                253
# IL17A                         0                  1                  3
# TP53                          4                  7                 37
# MAPK1                        11                 21                175
# CCRL2                         5                  1                 23
# BTK                           5                  6                 53
# CMKLR1                        2                  3                 12
# IL17B                         1                  2                  6
# TNFRSF13C                     0                  2                  7
# CD6                           1                  0                  3
# CTSG                          0                  0                  7
# NOTCH2                       11                 29                206
# TNFRSF4                       1                  1                  3
# ...                         ...                ...                ...
# CD97                         22                 52                283
# POS_C(8)                   1775               1804               2785
# POS_A(128)                20259              21862              36414
# POS_F(0.125)                 26                 25                 42
# POS_D(2)                    455                462                700
# POS_B(32)                  5871               6500               9547
# POS_E(0.5)                   98                102                160
# NEG_C(0)                      3                 10                 14
# NEG_D(0)                      2                  2                  1
# NEG_E(0)                      3                  1                  5
# NEG_A(0)                      0                  7                 10
# NEG_H(0)                      1                  1                  5
# NEG_G(0)                      0                  2                  3
# NEG_F(0)                      3                  3                  2
# NEG_B(0)                      0                  4                 11
# EEF1G                        57                130                979
# TUBB                          1                  6                 30
# TBP                           3                  2                 20
# POLR2A                        4                 27                102
# GUSB                          4                  5                 43
# HPRT1                         0                 11                 57
# GAPDH                        98                152               2283
# SDHA                          2                  3                 38
# OAZ1                         48                 86                735
# PPIA                          5                  5                 36
# G6PD                          4                 13                 84
# RPL19                        73                201               1701
# POLR1B                        0                  1                 13
# ABCF1                         6                  6                 46
# ALAS1                         3                  6                 44
#
#               MGH002_CD14_w0_05  MGH004_CD14_w0_09  MGH007_CD14_w0_10  \
# VTN                           0                  2                  1
# HLA-DQB1                     11                  0                  2
# KIT                           1                  3                  2
# SOCS3                        15                  7                206
# TCF7                          1                  0                  1
# IKBKB                         7                 17                 61
# ITGA6                         2                  2                  7
# CXCR4                        25                 31                496
# NFKBIZ                       12                 25                277
# MAPK14                       21                 62                183
# IL32                       1657               7155              12769
# CFB                           0                  4                  6
# CXCL1                         3                  2                 20
# CEACAM1                       1                  3                 12
# C8A                           0                  4                  5
# CFP                          13                 40                197
# LILRA5                       17                 82                333
# IL10RA                       38                126                385
# IL17A                         1                  4                  3
# TP53                          4                 14                 76
# MAPK1                        17                 44                145
# CCRL2                         1                  4                 30
# BTK                           8                 30                 72
# CMKLR1                        1                 12                 41
# IL17B                         1                  1                  4
# TNFRSF13C                     0                  2                  1
# CD6                           0                  1                  4
# CTSG                          0                  0                  4
# NOTCH2                       27                 98                237
# TNFRSF4                       0                  0                  3
# ...                         ...                ...                ...
# CD97                         38                 83                386
# POS_C(8)                   1463               1677               2971
# POS_A(128)                14580              17211              35132
# POS_F(0.125)                 21                 19                 48
# POS_D(2)                    274                389                654
# POS_B(32)                  4595               5580               9536
# POS_E(0.5)                   64                 85                160
# NEG_C(0)                      3                  1                 11
# NEG_D(0)                      0                  3                  5
# NEG_E(0)                      2                  6                  9
# NEG_A(0)                      2                  3                 12
# NEG_H(0)                      2                  4                  6
# NEG_G(0)                      1                  1                  5
# NEG_F(0)                      3                  2                 11
# NEG_B(0)                      3                  2                  7
# EEF1G                       111                399               1052
# TUBB                          2                 11                 26
# TBP                           2                 12                 26
# POLR2A                        5                 20                105
# GUSB                          5                  6                 32
# HPRT1                         6                 23                 48
# GAPDH                       216                400               1994
# SDHA                          4                 11                 53
# OAZ1                         86                177                863
# PPIA                          4                  6                 28
# G6PD                         11                 22                 81
# RPL19                       193                521               1665
# POLR1B                        1                  5                 12
# ABCF1                         7                 16                 66
# ALAS1                         0                  4                 16
#
#              CodeClass_THR   Accession_THR  GSM973583  GSM973584  GSM973585  \
# VTN             Endogenous     NM_000638.3         20         44         36
# HLA-DQB1        Endogenous     NM_002123.3        790       4686       4274
# KIT             Endogenous     NM_000222.1         42         43         32
# SOCS3           Endogenous     NM_003955.3       4265       8859       6741
# TCF7            Endogenous     NM_003202.2         44         81         59
# IKBKB           Endogenous     NM_001556.1        403        668        634
# ITGA6           Endogenous     NM_000210.1         48         51         53
# CXCR4           Endogenous     NM_003467.2      12664      23775      24608
# NFKBIZ          Endogenous  NM_001005474.1       5491      10013      10869
# MAPK14          Endogenous     NM_001315.1       2011       3327       3390
# IL32            Endogenous  NM_001012633.1     144575     132897     118298
# CFB             Endogenous     NM_001710.5         59         95         91
# CXCL1           Endogenous     NM_001511.1       1512       1996       2360
# CEACAM1         Endogenous     NM_001712.3         63         31         45
# C8A             Endogenous     NM_000562.2         33         45         46
# CFP             Endogenous  NM_001145252.1        341        395        482
# LILRA5          Endogenous     NM_181879.1        509        671        735
# IL10RA          Endogenous     NM_001558.2       4533       7905       8412
# IL17A           Endogenous     NM_002190.2         28         29         31
# TP53            Endogenous     NM_000546.2         54         47         73
# MAPK1           Endogenous     NM_002745.4       1330       2114       2670
# CCRL2           Endogenous     NM_003965.4        285        368        460
# BTK             Endogenous     NM_000061.1       1181       2350       2435
# CMKLR1          Endogenous     NM_004072.1        178        266        376
# IL17B           Endogenous     NM_014443.2         36         26         24
# TNFRSF13C       Endogenous     NM_052945.3         44         52         57
# CD6             Endogenous     NM_006725.3         55         63         66
# CTSG            Endogenous     NM_001911.2         37         18         24
# NOTCH2          Endogenous     NM_024408.2       2923       4689       5768
# TNFRSF4         Endogenous     NM_003327.2         35         38         48
# ...                    ...             ...        ...        ...        ...
# CD97            Endogenous     NM_078481.2       2951       4886       5417
# POS_C(8)          Positive    ERCC_00002.1       1512       1340       1316
# POS_A(128)        Positive    ERCC_00117.1      18228      15080      16338
# POS_F(0.125)      Positive    ERCC_00034.1         55         42         42
# POS_D(2)          Positive    ERCC_00092.1        421        329        365
# POS_B(32)         Positive    ERCC_00112.1       5243       4402       4651
# POS_E(0.5)        Positive    ERCC_00035.1         81         48         81
# NEG_C(0)          Negative    ERCC_00019.1         28         29         31
# NEG_D(0)          Negative    ERCC_00076.1         15         19         16
# NEG_E(0)          Negative    ERCC_00098.1         19         29         23
# NEG_A(0)          Negative    ERCC_00096.1         14         17         19
# NEG_H(0)          Negative    ERCC_00154.1         21         17         19
# NEG_G(0)          Negative    ERCC_00144.1         34         31         31
# NEG_F(0)          Negative    ERCC_00126.1          9          7         12
# NEG_B(0)          Negative    ERCC_00041.1         19         12         13
# EEF1G           Endogenous     NM_001404.4       8918      16367      18203
# TUBB            Endogenous     NM_178014.2        657       1066       1180
# TBP             Endogenous     NM_003194.3        123        176        167
# POLR2A          Endogenous     NM_000937.2       1321       2214       2206
# GUSB            Endogenous     NM_000181.1        430        588        743
# HPRT1           Endogenous     NM_000194.1        432        750        806
# GAPDH           Endogenous     NM_002046.3       9617      16533      18161
# SDHA            Endogenous     NM_004168.1        466        750        896
# OAZ1            Endogenous     NM_004152.2      10533      16310      19761
# PPIA            Endogenous     NM_021130.2        347        662        523
# G6PD            Endogenous     NM_000402.2       1194       1739       2175
# RPL19           Endogenous     NM_000981.3      19608      39295      39213
# POLR1B          Endogenous     NM_019014.3         65        100        159
# ABCF1           Endogenous     NM_001090.2        648       1057       1063
# ALAS1           Endogenous     NM_000688.4        119        153        178
#
#               GSM973586  GSM973587  GSM973588  GSM973589  GSM973590  \
# VTN                  27         22         23          9         22
# HLA-DQB1             27         11         16       1778       2381
# KIT                  36         35         27         22         37
# SOCS3              5401       4226       2073       3250       6298
# TCF7                138         38         44         30         58
# IKBKB               448        463        276        285        683
# ITGA6                70         42         34         34         36
# CXCR4             20743       7071       9081      13677      28984
# NFKBIZ             8641       4337       2776       5294      12161
# MAPK14             2257       1460        903       1326       2957
# IL32             156210     152869     145461     114000     142640
# CFB                 100         57         56         52        113
# CXCL1              1447        853        602       1303       2316
# CEACAM1              56         26         35         33         25
# C8A                  36         26         25         23         31
# CFP                 368        125        182        251        416
# LILRA5              684        556        310        274        827
# IL10RA             6019       3167       2604       4114      10730
# IL17A                32         23         21         10         35
# TP53                 34         21         35         47         59
# MAPK1              1585        418        686       1124       2459
# CCRL2               377        126        158        181        439
# BTK                1825       1089        758       1135       2413
# CMKLR1              207        216         83         77        233
# IL17B                35         16         12         12         28
# TNFRSF13C            58         47         42         45         59
# CD6                 125         37         28         39         63
# CTSG                 24         20         17         15         73
# NOTCH2             4359       1995       1644       2783       6182
# TNFRSF4              29         36         18         28         42
# ...                 ...        ...        ...        ...        ...
# CD97               3693       1255       1360       3277       5741
# POS_C(8)           1430       1460       1490       1060       1347
# POS_A(128)        16922      17079      19240      13850      18780
# POS_F(0.125)         47         37         48         38         43
# POS_D(2)            414        415        461        298        389
# POS_B(32)          4963       5145       5342       3782       5041
# POS_E(0.5)           75         84         92         61        100
# NEG_C(0)             29         31         26         22         32
# NEG_D(0)             15         16         13          7         11
# NEG_E(0)             19          8         13         10         26
# NEG_A(0)             18         14         12         10         18
# NEG_H(0)             18         23         20         15         24
# NEG_G(0)             32         32         22         24         21
# NEG_F(0)             14         15         10          5         11
# NEG_B(0)             10         15         18          6         11
# EEF1G             12934       7365       6062       7667      20715
# TUBB                699        293        388        515       1190
# TBP                 123         77         56         65        125
# POLR2A             1791       1216        780       1104       2828
# GUSB                942        295        245        316        880
# HPRT1               650        253        261        379        831
# GAPDH             11140       3672       5201       8277      15395
# SDHA                712        285        281        398        804
# OAZ1              13204       2380       4831       8556      17067
# PPIA                540        243        275        340        811
# G6PD               1695        922        596       1013       2074
# RPL19             30347      18106      12933      18225      42762
# POLR1B              106         47         38         42        112
# ABCF1              1102        626        394        600       1344
# ALAS1               138         85         56         83        128
#
#               GSM973591  GSM973592
# VTN                  27         20
# HLA-DQB1           8212       2225
# KIT                  29         31
# SOCS3              3883       4945
# TCF7                 62         33
# IKBKB               638        400
# ITGA6                38         39
# CXCR4             25473      13862
# NFKBIZ             8858       5974
# MAPK14             3370       1787
# IL32             130597     122686
# CFB                  86         63
# CXCL1              2350       2209
# CEACAM1              45         25
# C8A                  29         21
# CFP                 421        335
# LILRA5              262        521
# IL10RA            10596       4631
# IL17A                26         21
# TP53                 71         43
# MAPK1              2937       1406
# CCRL2               241        254
# BTK                2847       1568
# CMKLR1              621        114
# IL17B                36         17
# TNFRSF13C            64         43
# CD6                 105         45
# CTSG                101         15
# NOTCH2             5641       3178
# TNFRSF4              39         18
# ...                 ...        ...
# CD97               6999       3240
# POS_C(8)           1187       1231
# POS_A(128)        14911      16150
# POS_F(0.125)         36         34
# POS_D(2)            336        321
# POS_B(32)          4338       4638
# POS_E(0.5)           59         67
# NEG_C(0)             24         23
# NEG_D(0)             12          6
# NEG_E(0)             22         12
# NEG_A(0)             22         10
# NEG_H(0)             15         12
# NEG_G(0)             27         30
# NEG_F(0)              9          8
# NEG_B(0)              8          8
# EEF1G             18924      10837
# TUBB               1285        608
# TBP                 194         88
# POLR2A             2271       1655
# GUSB                738        472
# HPRT1               882        491
# GAPDH             21053      11178
# SDHA               1019        663
# OAZ1              19135      11997
# PPIA                754        400
# G6PD               2192       1435
# RPL19             42327      23775
# POLR1B              126         74
# ABCF1              1095        870
# ALAS1               163        135
#
# [520 rows x 18 columns]

# %%
print cmb_data.columns.values
# Out:
# ['BWH006_CD14_w0_04' 'BWH008_CD14_w0_09' 'MGH001_CD14_w0_07'
#  'MGH002_CD14_w0_05' 'MGH004_CD14_w0_09' 'MGH007_CD14_w0_10' 'GSM973583'
#  'GSM973584' 'GSM973585' 'GSM973586' 'GSM973587' 'GSM973588' 'GSM973589'
#  'GSM973590' 'GSM973591' 'GSM973592']

# %%
cmb_data_path = base_path+u"/combo_nanostring_data.csv"
cmb_data.to_csv(path_or_buf=cmb_data_path, 
           columns=None, header=True, index=True,)

# %%
sns.jointplot(x='OURS', y='THEIRS',
              data=np.log10(cmb_cpm_mean+1), kind='scatter',
              xlim=(0,7), ylim=(0,7)
             );

plt.suptitle("Comparison of our {cell} Nanostring data vs published.".format(cell=cell_type), y=1,);

# %% [markdown]
# ### Lets look at the external controls

# %%
cmb_data_extra_cols.head()
# Out:
#          CodeClass_OUR Accession_OUR CodeClass_THR Accession_THR
# VTN         Endogenous   NM_000638.3    Endogenous   NM_000638.3
# HLA-DQB1    Endogenous   NM_002123.3    Endogenous   NM_002123.3
# KIT         Endogenous   NM_000222.2    Endogenous   NM_000222.1
# SOCS3       Endogenous   NM_003955.3    Endogenous   NM_003955.3
# TCF7        Endogenous   NM_003202.2    Endogenous   NM_003202.2

# %%
cmb_data_extra_cols.CodeClass_OUR.unique()
# Out:
# array(['Endogenous', 'Positive', 'Negative', 'Housekeeping'], dtype=object)

# %%
cmb_data_extra_cols.CodeClass_THR.unique()
# Out:
# array(['Endogenous', 'Positive', 'Negative'], dtype=object)

# %%
pos_ctrl = list(cmb_data_extra_cols.query(""" CodeClass_OUR == "Positive" """).index.values)
neg_ctrl = list(cmb_data_extra_cols.query(""" CodeClass_OUR == "Negative" """).index.values)
hsk_gene = list(cmb_data_extra_cols.query(""" CodeClass_OUR == "Housekeeping" """).index.values)
bth_ctrl = pos_ctrl + neg_ctrl
pan_gene = list(cmb_data_extra_cols[cmb_data_extra_cols.CodeClass_OUR.apply(lambda i: i in ['Housekeeping','Endogenous'])].index.values)

# %%
bth_ctrl
# Out:
# ['POS_C(8)',
#  'POS_A(128)',
#  'POS_F(0.125)',
#  'POS_D(2)',
#  'POS_B(32)',
#  'POS_E(0.5)',
#  'NEG_C(0)',
#  'NEG_D(0)',
#  'NEG_E(0)',
#  'NEG_A(0)',
#  'NEG_H(0)',
#  'NEG_G(0)',
#  'NEG_F(0)',
#  'NEG_B(0)']

# %%
cmb_cpm_mean.head()
# Out:
# source           OURS       THEIRS
# VTN         27.268306    17.888145
# HLA-DQB1   279.626299  1395.749960
# KIT         54.113462    25.036577
# SOCS3     1204.189985  3443.938653
# TCF7        21.901164    40.591074

# %%
sns.jointplot(x='OURS', y='THEIRS',
              data=np.log10(cmb_cpm_mean.loc[pos_ctrl]+1), kind='scatter',
              xlim=(0,7), ylim=(0,7)
             );

plt.suptitle("(Pos Ctrls) Comparison of our {cell} Nanostring data vs published.".format(cell=cell_type), y=1,);

# %%
sns.jointplot(x='OURS', y='THEIRS',
              data=np.log10(cmb_cpm_mean.loc[neg_ctrl]+1), kind='scatter',
              xlim=(0,7), ylim=(0,7)
             );

plt.suptitle("(Neg Ctrls) Comparison of our {cell} Nanostring data vs published.".format(cell=cell_type), y=1,);

# %%
cmb_cpm_mean.loc[neg_ctrl].head()
# Out:
# source          OURS     THEIRS
# NEG_C(0)  179.277108  20.998254
# NEG_D(0)   60.870736   9.856633
# NEG_E(0)  106.585016  12.274479
# NEG_A(0)  109.453229  11.059749
# NEG_H(0)   68.211021  14.408876

# %%
sns.jointplot(x='OURS', y='THEIRS',
              data=np.log10(cmb_cpm_mean.loc[hsk_gene]+1), kind='scatter',
              xlim=(0,7), ylim=(0,7)
             );

plt.suptitle("(Housekeeping) Comparison of our {cell} Nanostring data vs published.".format(cell=cell_type), y=1,);

# %%
sns.jointplot(x='OURS', y='THEIRS',
              data=np.log10(cmb_cpm_mean.loc[pan_gene]+1), kind='scatter',
              xlim=(0,7), ylim=(0,7)
             );

plt.suptitle("(Panel Genes) Comparison of our {cell} Nanostring data vs published..".format(cell=cell_type), y=1,);
