# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
path = "/home/gus/MEGAsync/zim/main/Yale/Collaborations/Hongyu-tsetse/gmm_to_gff_pipeline/pipeline_runs/gmm_to_gff_testing_v2/get_nearest_k_features/snp_list_OT_1_with_p_value.nearest.bed"

# %%
headers = ["SNP_chrom",
           "SNP_start",
           "SNP_end",
           "feature_set_name",
           "chrom",
           "chromStart",
           "chromEnd",
           "name",
           "score",
           "strand",
           "thickStart",
           "thickEnd",
           "itemRgb",
           "blockCount",
           "blockSizes",
           "blockStarts",
           "distance"
          ]

# %%
nearest = pd.read_csv(path, sep="\t", names=headers)
nearest
# Out:
#        SNP_chrom  SNP_start  SNP_end      feature_set_name        chrom  \
# 0     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 1     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 2     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 3     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 4     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 5     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 6     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 7     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 8     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 9     Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 10    Scaffold10    1586111  1586112       novel_mapped_tx   Scaffold10
# 11    Scaffold10    1586111  1586112  official_annotations   Scaffold10
# ...

# %%
snp = ["SNP_chrom","SNP_start","SNP_end"]

hit = ["feature_set_name",
"chrom",
"chromStart",
"chromEnd",
"name",
"score",
"strand",
"thickStart",
"thickEnd",
"itemRgb",
"blockCount",
"blockSizes",
"blockStarts",
"distance"]

# %%
# pd.pivot_table(data=nearest, 
#                values=None, index=None, columns=None, 
#                aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')

# %%
nearest.query(""" abs(distance) <= 0 """)
# Out:
#        SNP_chrom  SNP_start  SNP_end      feature_set_name        chrom  \
# 31   Scaffold102     330091   330092  official_annotations  Scaffold102
# 63   Scaffold102     398873   398874  official_annotations  Scaffold102
# 83   Scaffold107     284001   284002  official_annotations  Scaffold107
# 103   Scaffold13    1603124  1603125  official_annotations   Scaffold13
# 113  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 114  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 115  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 116  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 117  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 118  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 119  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# 120  Scaffold151     406663   406664       novel_mapped_tx  Scaffold151
# ...

# %%
nearest.query(""" 100 < abs(distance) <= 10000 """)
# Out:
#        SNP_chrom  SNP_start  SNP_end      feature_set_name        chrom  \
# 21   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 22   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 23   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 24   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 25   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 26   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 27   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 28   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 29   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 30   Scaffold102     330091   330092       novel_mapped_tx  Scaffold102
# 32   Scaffold102     330091   330092  official_annotations  Scaffold102
# 64   Scaffold102     398873   398874  official_annotations  Scaffold102
# ...
