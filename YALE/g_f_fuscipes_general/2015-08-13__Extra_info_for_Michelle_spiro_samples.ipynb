# %% [markdown]
# # Purpose:
#
# - Michelle wants extra info for the flies that she is testing for spiroplasma.
#     - sex
#     - tryp status
#     - Location of of the `AJ` samples

# %% [markdown]
# ## Imports:

# %%
# imports
import datetime as dt

import csv
import itertools
import os
import re

import pandas as pd
pd.options.display.max_rows = 1000
import numpy as np
import datetime as dt

import scipy

import munch

# %% [markdown]
# ## File paths:

# %%
# define paths to files
spring_summer = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/collection_data/2014_spring_summer_from_rob.xlsx"
fall =          "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/collection_data/2014_fall_for_pandas.xlsx"
december = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/collection_data/DEC_2014_survey_for_pandas.xlsx"

# %%
village_id_map_path = "/home/gus/Dropbox/uganda_data/data_repos/field_data/locations/names/uganda_village_id_map.csv"

# %%
# !cat $village_id_map_path
# Out:
# ABO,Abok,
# ACA,Acankoma,
# AG,Agoba B,
# AIN,Aina,
# AKA,Akayo-debe,
# AKA,Akayodebe,
# AKY,AkayoIdebe,
# ALE,Alege,
# ALI,Alim,
# ALI,Aliodri,
# AMI,Aminikawach,
# APU,Aputu-Lwaa,
# ASW,Aswa Bridge,
# ATM,Atanga Mission,
# BOL,Bola,
# CE,Cefo,Moyo
# CHU,Chua,
# DUK,Duku,
# GAN,Gangu,
# GOR,Gorodona,
# JIA,Jiako,
# KIL,Kilak,
# KTC,Kitgum town council,
# LAG,Lagwel,
# LAK,Lakwala,
# LEA,Lea,
# LIB,Liba,
# MOP,Moyipi,
# MWA,Mwanya,
# NGO,Ngomoromo,
# OCA,Ocala,
# OCL,Ocol,
# OCU,Oculoi,
# OD,Odworo,
# OGU,Oguk,
# OKS,Okidi South,
# OLE,Olepo,
# OLO,Olobo,
# OLW,Olwi,
# OMI,Omido,
# OPU,Opuyu,
# ORB,Orubakulemi,
# ORI,Ori,
# ORV,Orivu,
# OSG,Osugo East,
# OSG,Osugo West,
# PAW,Pawor,
# TEO,Te-Okot,
# TUM,Tumangu,
# UWA,Uganda Wildlife Authority,
# WEN,Wende,
# ,,
# ,,
# ESI,Esia,Adjumani
# OYA,Oringya,Adjumani
# PAG,Pagirinya,Adjumani
# MAD,Madilu,Adjumani
# ,,
# ,,
# LPI,Laropi,Moyo
# BLA,Belameling,Moyo

# %% [markdown]
# ----
# # Helper functions

# %%
def date_is_between(test_date, start, end):
    
    try:
        return start <= test_date <= end
    except TypeError as exc:
        if "can't compare datetime" in exc.message:
            return False
        else:
            raise

# %%
def get_village_id_map(village_id_map_path):
    """
    Generates and returns a `dict` mapping the long-form village names to the letter codes.
    Letter codes map back to themselves to ensure a one way mapping.  
    Enforces both be all UPPERcase to allow case insensitivity as long as
    the map is used like: `map[text.upper()]`.
    :return: `dict`
    """

    village_id_map = {}

    with open(village_id_map_path, 'rb') as csv_file:
        village_ids = csv.reader(csv_file, delimiter=',')
        for pair in village_ids:
            village_id_map[unicode(pair[0].upper())] = unicode(pair[0].upper())
            village_id_map[unicode(pair[1].upper())] = unicode(pair[0].upper())

    return village_id_map

# %%
def load_xl_sheets(xl_path):
    dfs = munch.Munch()
    
    xls = pd.ExcelFile(xl_path)
    
    workbook_name = os.path.basename(xl_path)
    
    for sheet in xls.sheet_names:
        if sheet.upper().startswith("DISSECT"):
            worksheet_df = xls.parse(sheetname=sheet, 
                                header=0, 
                                skiprows=None, skip_footer=0, 
                                index_col=None, parse_cols=None, 
                                parse_dates=False, date_parser=None, 
                                na_values=['NA'], 
                                thousands=None, chunksize=None, 
                                convert_float=False, 
                                has_index_names=False, converters=None)
            
            worksheet_df['workbook'] = workbook_name
            worksheet_df['worksheet'] = sheet
            
            dfs[sheet] = worksheet_df 
            
    return dfs

# %%
def recode_villages(df):
    map_func = lambda x: village_id_map[x.upper()]
        
    new_codes = df.Village.apply(map_func)
    df.Village = new_codes

# %%
def recode_dead(df):
    def recode_func(x):
        # this is treated as an unknown case
        if pd.isnull(x):
            return x

        x = unicode(x)

        # True means DEAD
        # False means LIVE or NOT-DEAD
        # None means unknown

        try:
            # deal with Live type cases
            if x.upper().startswith('L'):
                return False


            if x.startswith('0'):
                return False


            # deal with Dead type cases
            if x.upper().startswith('D'):
                return True


            if x.startswith('1'):
                return True


            # deal with unknown type cases
            if x.upper().startswith('UN'):
                return None
        except AttributeError:
            return x

        msg = "The value {x} was not expected and this function must be corrected to continue.".format(x=x)
        raise ValueError(msg)

    new_dead = df.Dead.apply(recode_func)
    df.Dead = new_dead

##########################################

def recode_teneral(df):
    def recode_func(x):

        # this is treated as an unknown case
        if pd.isnull(x):
            return x

        x = unicode(x)

        # True means teneral
        # False means NOT-teneral
        # None means unknown

        try:
            # deal with NOT-teneral type cases
            if x.upper().startswith('N'):
                return False

            if x.startswith('0'):
                return False

            # deal with Teneral type cases
            if x.upper().startswith('T'):
                return True
            
            if x.startswith('1'):
                return True


            # Deal with unknown type cases
            if x.upper().startswith('UN'):
                return x
        except AttributeError:
            return x

        msg = "The value {x} was not expected and this function must be corrected to continue.".format(x=x)
        raise ValueError(msg)
    
    
    new_teneral = df.Teneral.apply(recode_func)
    df.Teneral = new_teneral

##########################################

def recode_positives(df):
    def recode_func(x):
        # this is treated as an unknown case
        if pd.isnull(x):
            return x

        y = unicode(x)

        # deal with Unknown type cases
        if y.upper().startswith('UN'):
            return None

        if y.upper().startswith('DEAD'):
            return None


        # deal with Positive type cases
        if y.startswith('1'):
            return True


        if y.upper().startswith('TRUE'):
            return True

        if y.upper().startswith('P'):
            return True

        if y.upper().startswith('Y'):
            return True


        # deal with Negative type cases
        if y.upper().startswith('NO'):
            return False

        if y.upper().startswith('FALSE'):
            return False


        if y.startswith('0'):
            return False


        msg = "The value {x} was not expected and this function must be corrected to continue.".format(x=x)
        raise ValueError(msg)


    new_prob = df.prob.apply(recode_func)
    df.prob = new_prob
    
    new_midgut = df.midgut.apply(recode_func)
    df.midgut = new_midgut
    
    new_sal_gland = df.sal_gland.apply(recode_func)
    df.sal_gland = new_sal_gland

##########################################

def recode_species(df):

    recode_func = lambda x: ''.join(x.split('.')).capitalize()

    new_Species = df.Species.apply(recode_func)
    df.Species = new_Species

##########################################

def recode_sex(df):

    recode_func = lambda x: x.upper()

    new_Sex = df.Sex.apply(recode_func)
    df.Sex = new_Sex
    
##########################################

date_delim = re.compile('[\./-]')

def cast_unicode_as_date(x):
    if not isinstance(x, unicode):
        return x
    
    parts = date_delim.split(x)
    
    if len(parts) != 3:
        return x
    
    if len(parts[0]) != 4:
        return x
    
    return dt.datetime(int(parts[0]), int(parts[1]), int(parts[2]))

def recode_date(df):
    new_date = df.Date.apply(cast_unicode_as_date)
    df.Date = new_date

##########################################

fly_no_delim = re.compile('[\W\s]', re.UNICODE)

def split_number(x):
#     ipdb.set_trace()
    
    # to prevent unicode creating a string with a '.' AFTER
    # the numbert we are intersted in!
    try:
        if isinstance(x,float):
            return int(x)
    except ValueError as exc:
        if 'NAN' in exc.message.upper():
            return x
    
    x = unicode(x)
    parts = fly_no_delim.split(x)
    
    try:
        number = int(parts[-1])
        return number
    except ValueError:
        return x


def recode_fly_number(df):
    
    new_fly_number = df.Fly_Number.apply(split_number)
    df.Fly_Number = new_fly_number

# %%
def aggregate_column_from_df_list(df_list, col_name):
    agg_data = []
    for df in df_list:
        agg_data.extend(list(df[col_name]))
        
    
    return agg_data

# %% [markdown]
# ### Functions that add new columns

# %%
def add_infection_state_col(df):
    df['infection_state'] = df[['prob','midgut','sal_gland']].any(skipna=True,axis=1)

# %% [markdown]
# ## Recode Fly_Number

# %%
# pdb
# import ipdb

# %%
dfp = pd.read_pickle(pickle_out_path)
dfp.reset_index(level=0, inplace=True)
dfp.drop(['index'], axis=1, inplace=True)
recode_fly_number(dfp)
dfp = dfp.query("Species in ['Gff']")
dfp
# Out:
#      Comment       Date   Dead  Fly_Number Hunger_stage  Kept_in Sex Species  \
# 0        NaN 2014-07-22  False           1            2     EtOH   F     Gff
# 1        NaN 2014-07-22  False           2            3     EtOH   F     Gff
# 2        NaN 2014-07-22  False           3            3     EtOH   M     Gff
# 3        NaN 2014-07-22  False           4            3     EtOH   M     Gff
# 4        NaN 2014-07-22  False           5            3     EtOH   M     Gff
# 5        NaN 2014-07-22  False           6            2     EtOH   M     Gff
# 6        NaN 2014-07-22  False           7            3     EtOH   F     Gff
# 7        NaN 2014-07-22  False           8            3     EtOH   F     Gff
# 8        NaN 2014-07-22  False           9            3     EtOH   F     Gff
# 9        NaN 2014-07-22  False          10            2     EtOH   F     Gff
# 10       NaN 2014-07-22  False          11            3     EtOH   F     Gff
# 11       NaN 2014-07-22  False          12            3     EtOH   F     Gff
# 12       NaN 2014-07-22  False          13            3     EtOH   M     Gff
# 13       NaN 2014-07-22  False          14            2     EtOH   M     Gff
# 14       NaN 2014-07-22  False          15            3     EtOH   M     Gff
# 15       NaN 2014-07-22  False          16            3     EtOH   M     Gff
# 16       NaN 2014-07-22  False          17            3     EtOH   F     Gff
# 17       NaN 2014-07-22  False          18            3     EtOH   F     Gff
# 18       NaN 2014-07-22   True          19          NaN     EtOH   M     Gff
# 19       NaN 2014-07-22   True          20          NaN     EtOH   M     Gff
# 20       NaN 2014-07-22   True          21          NaN     EtOH   M     Gff
# 21       NaN 2014-07-22   True          22          NaN     EtOH   M     Gff
# 22       NaN 2014-07-22   True          23          NaN     EtOH   M     Gff
# 23       NaN 2014-07-22  False          24          NaN     EtOH   F     Gff
# 24       NaN 2014-07-22  False          25          NaN     EtOH   F     Gff
# 25       NaN 2014-07-22  False          26          NaN     EtOH   F     Gff
# 26       NaN 2014-07-22  False          27          NaN     EtOH   M     Gff
# 27       NaN 2014-07-22  False          28          NaN     EtOH   M     Gff
# 28       NaN 2014-07-22  False          29          NaN     EtOH   M     Gff
# 29       NaN 2014-07-22  False          30          NaN     EtOH   M     Gff
# ...      ...        ...    ...         ...          ...      ...  ..     ...
# 6926       0 2014-12-23  False         669            2  Ethanol   F     Gff
# 6927       0 2014-12-23  False         670            2  Ethanol   F     Gff
# 6928       0 2014-12-23  False         671            2  Ethanol   F     Gff
# 6929       0 2014-12-23  False         672            0  Ethanol   F     Gff
# 6930       0 2014-12-23  False         673            0  Ethanol   F     Gff
# 6931       0 2014-12-23  False         674            0  Ethanol   F     Gff
# 6932       0 2014-12-23  False         675            0  Ethanol   M     Gff
# 6933       0 2014-12-23  False         676            0  Ethanol   M     Gff
# 6934       0 2014-12-23  False         677            0  Ethanol   M     Gff
# 6935       0 2014-12-23  False         678            0  Ethanol   M     Gff
# 6936       0 2014-12-23   True         679            0  Ethanol   M     Gff
# 6937       0 2014-12-23   True         680            0  Ethanol   M     Gff
# 6938       0 2014-12-23   True         681            0  Ethanol   M     Gff
# 6939       0 2014-12-23   True         682            0  Ethanol   M     Gff
# 6940       0 2014-12-23  False         683            2  Ethanol   F     Gff
# 6941       0 2014-12-23  False         684            2  Ethanol   F     Gff
# 6942       0 2014-12-23   True         685            0  Ethanol   F     Gff
# 6943       0 2014-12-23   True         686            0  Ethanol   M     Gff
# 6944       0 2014-12-23   True         687            0  Ethanol   M     Gff
# 6945       0 2014-12-23   True         688            0  Ethanol   M     Gff
# 6946       0 2014-12-23  False         689            0  Ethanol   F     Gff
# 6947       0 2014-12-23  False         690            2  Ethanol   M     Gff
# 6948       0 2014-12-23  False         691            3  Ethanol   F     Gff
# 6949       0 2014-12-23  False         692            2  Ethanol   F     Gff
# 6950       0 2014-12-23  False         693            2  Ethanol   F     Gff
# 6951       0 2014-12-23  False         694            2  Ethanol   M     Gff
# 6952       0 2014-12-23   True         695            0  Ethanol   F     Gff
# 6953       0 2014-12-23  False         696            0  Ethanol   M     Gff
# 6954       0 2014-12-23  False         697            0  Ethanol   M     Gff
# 6955       0 2014-12-23  False         698            0  Ethanol   M     Gff
#
#      Teneral  Trap_No Village Wing_fray infection_state midgut   prob  \
# 0      False        1     UWA         2           False  False  False
# 1      False        1     UWA         2           False  False  False
# 2      False        1     UWA         2           False  False  False
# 3      False        1     UWA         2           False  False  False
# 4      False        1     UWA         2           False  False  False
# 5      False        1     UWA         2           False  False  False
# 6      False        1     UWA         2           False  False  False
# 7      False        1     UWA         2           False  False  False
# 8      False        1     UWA         3           False  False  False
# 9      False        1     UWA         2           False  False  False
# 10     False        1     UWA         2           False  False  False
# 11     False        1     UWA         2           False  False  False
# 12     False        1     UWA         2           False  False  False
# 13     False        1     UWA         2           False  False  False
# 14     False        1     UWA         2           False  False  False
# 15     False        1     UWA         2           False  False  False
# 16     False        1     UWA         3           False  False  False
# 17     False        1     UWA         3           False  False  False
# 18     False        1     UWA       NaN           False    NaN    NaN
# 19     False        1     UWA       NaN           False    NaN    NaN
# 20     False        1     UWA       NaN           False    NaN    NaN
# 21     False        1     UWA       NaN           False    NaN    NaN
# 22     False        1     UWA       NaN           False    NaN    NaN
# 23      True        1     UWA       NaN           False    NaN    NaN
# 24      True        1     UWA       NaN           False    NaN    NaN
# 25      True        1     UWA       NaN           False    NaN    NaN
# 26      True        1     UWA       NaN           False    NaN    NaN
# 27      True        1     UWA       NaN           False    NaN    NaN
# 28      True        1     UWA       NaN           False    NaN    NaN
# 29      True        1     UWA       NaN           False    NaN    NaN
# ...      ...      ...     ...       ...             ...    ...    ...
# 6926   False        5     OCU         3           False  False  False
# 6927   False        5     OCU         2           False  False  False
# 6928   False        5     OCU         2           False  False  False
# 6929    True        5     OCU         0           False  False  False
# 6930    True        5     OCU         0           False  False  False
# 6931    True        5     OCU         0           False  False  False
# 6932    True        5     OCU         0           False  False  False
# 6933    True        5     OCU         0           False  False  False
# 6934    True        5     OCU         0           False  False  False
# 6935    True        5     OCU         0           False  False  False
# 6936   False        5     OCU         0           False  False  False
# 6937   False        5     OCU         0           False  False  False
# 6938   False        5     OCU         0           False  False  False
# 6939   False        5     OCU         0           False  False  False
# 6940   False       19     AMI         3           False  False  False
# 6941   False       19     AMI         3           False  False  False
# 6942   False       19     AMI         0           False  False  False
# 6943   False       19     AMI         0           False  False  False
# 6944   False       19     AMI         0           False  False  False
# 6945   False       19     AMI         0           False  False  False
# 6946   False       18     AMI         0           False  False  False
# 6947   False       18     AMI         2           False  False  False
# 6948   False       18     AMI         2           False  False  False
# 6949   False       18     AMI         2           False  False  False
# 6950   False       17     AMI         2           False  False  False
# 6951   False       17     AMI         2           False  False  False
# 6952   False       17     AMI         0           False  False  False
# 6953    True       17     AMI         0           False  False  False
# 6954    True       17     AMI         0           False  False  False
# 6955    True       17     AMI         0           False  False  False
#
#      sal_gland                          workbook                   worksheet
# 0        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 1        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 2        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 3        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 4        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 5        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 6        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 7        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 8        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 9        False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 10       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 11       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 12       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 13       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 14       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 15       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 16       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 17       False  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 18         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 19         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 20         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 21         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 22         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 23         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 24         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 25         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 26         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 27         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 28         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# 29         NaN  2014_spring_summer_from_rob.xlsx       Dissection Data-Nwoya
# ...        ...                               ...                         ...
# 6926     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6927     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6928     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6929     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6930     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6931     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6932     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6933     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6934     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6935     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6936     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6937     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6938     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6939     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6940     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6941     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6942     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6943     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6944     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6945     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6946     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6947     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6948     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6949     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6950     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6951     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6952     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6953     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6954     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
# 6955     False   DEC_2014_survey_for_pandas.xlsx  Dissection data Dokolo-kab
#
# [6867 rows x 18 columns]

# %% [markdown]
# ----
# # Helpful constants

# %%
village_id_map = get_village_id_map(village_id_map_path)
