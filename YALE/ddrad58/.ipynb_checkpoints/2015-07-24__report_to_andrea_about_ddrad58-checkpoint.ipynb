# %% [markdown]
# ## Imports:

# %%
# imports
import csv

from collections import defaultdict

import pandas as pd
pd.set_option('display.max_columns', 60)

import munch

from IPython.display import display, HTML

import pybedtools as pbt

import sh

import tabulate
tbl = tabulate.tabulate

from spartan.utils.annotations.ensembl.gff3 import parse_gff3
from spartan.utils.annotations.ensembl.gff3 import parse_gff3_attributes

from spartan.utils.fastas import ParseFastA

from spartan.utils.files import tableFile2namedTuple

from spartan.utils.genome_specific.GfusI1 import GfusI1_0

from gs_ddRAD2015.scripts import ld_figures as ldfigs

# %% [markdown]
# ## File paths:

# %%
# File Paths

## LD analysis dir
ld_dir = "/home/gus/MEGAsync/projects/ddRAD_phase2/repos/ddRAD_phase2/scratch/gs_2015_ld/OT_MS_NB_indiv.geno.ld"


## Fasta file for renaming contigs ----------------------------------------------------------
fasta = "/home/gus/remote_mounts/louise/data/genomes/glossina_fuscipes/assemblies/GfusI1/Glossina-fuscipes-IAEA_SCAFFOLDS_GfusI1.fa"

## Functional annatation (Argot2)
fanno = "/home/gus/remote_mounts/louise/data/genomes/glossina_fuscipes/annotations/functional/GfusI1.1_pre/argot2_out/argot_functional_annotations_ts150.h5"

## For setting up the BEDTOOLS phase
btools_gene_models_gff3 = "/home/gus/remote_mounts/louise/data/genomes/glossina_fuscipes/annotations/Glossina-fuscipes-IAEA_BASEFEATURES_GfusI1.1.gff3"

## Input BEDs etc if using files
Top10_InfectionOverall_path = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/ddrad58/data_from_andrea/2015-02-26_bayescan_tables/Top10_InfectionOverall.bed"
Selected_PopPairwiseMSOT_Environm_path = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/ddrad58/data_from_andrea/2015-03-17_env_selection/Selected_PopPairwiseMSOT_Environm.bed"
Selected_PopPairwiseMSNB_Environm_path = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/ddrad58/data_from_andrea/2015-03-17_env_selection/Selected_PopPairwiseMSNB_Environm.bed"
Top10_corrected_PopPairwiseOverlap_Infection2015_path = "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/ddrad58/data_from_andrea/2015-07-23_overlap_infection/Top10_corrected_PopPairwiseOverlap_Infection2015.bed"
Top10_PopPairwiseOverlap_Environm_path= "/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/ddrad58/data_from_andrea/2015-02-26_bayescan_tables/Top10_PopPairwiseOverlap_Environm.bed"

# %%
# manual definition of bed data:

pcadapt_outliers_str = """Scaffold150	13772	13773
Scaffold150	13771	13772
Scaffold250	396213	396214
Scaffold144	565216	565217
Scaffold207	475991	475992
Scaffold368	310506	310507"""

# %%
# load LD analysis results
figs = ldfigs.Figures(out_dir=ld_dir, formats='png')
figs.load_data_tables()
ld_tables = munch.Munch(figs.d)
ld_tables.keys()
# Out:
# ld_figures: loading data_tables.
# ['ld',
#  'd_bins',
#  'contig_info',
#  'd_bin_v_others_melt',
#  'len_contigs_per_bin',
#  'd_bin_v_others',
#  'contigs_per_bin',
#  'mean_bin_r2_all',
#  'sp_contigs',
#  'ld_contig']

# %%
ld = ld_tables.ld
del(ld_tables)

# %%
# load BED files
Top10_InfectionOverall = pbt.BedTool(Top10_InfectionOverall_path)
Selected_PopPairwiseMSOT_Environm = pbt.BedTool(Selected_PopPairwiseMSOT_Environm_path)
Selected_PopPairwiseMSNB_Environm = pbt.BedTool(Selected_PopPairwiseMSNB_Environm_path)
Top10_corrected_PopPairwiseOverlap_Infection2015 = pbt.BedTool(Top10_corrected_PopPairwiseOverlap_Infection2015_path)
Top10_PopPairwiseOverlap_Environm = pbt.BedTool(Top10_PopPairwiseOverlap_Environm_path)

# load BED strings
pcadapt_outliers = pbt.BedTool(pcadapt_outliers_str,from_string=True)

# %%
# load gene models into pybedtools object and filter for only gene features
btools_gene_models_pbt = pbt.BedTool(btools_gene_models_gff3)
genes = btools_gene_models_pbt.filter(lambda x: x[2] == 'gene').saveas()

# %%
# load functional annotations
argot2 = pd.read_hdf(path_or_buf=fanno, key='dataframe')

# %%
argot2['gene_id'] = argot2.Sequence.apply(lambda x: x[:-3])
argot2_200 = argot2[argot2['Total Score'] >= 200]
argot2.head()
# Out:
#         Sequence Aspect       GO ID                                  Name  \
# 0  GFUI034947-PA      P  GO:0006508                           proteolysis
# 1  GFUI035874-PA      F  GO:0005515                       protein binding
# 2  GFUI033625-PA      P  GO:0005980            glycogen catabolic process
# 3  GFUI033625-PA      F  GO:0004134   4-alpha-glucanotransferase activity
# 4  GFUI033625-PA      F  GO:0004135  amylo-alpha-1,6-glucosidase activity
#
#    Total Score  Internal Confidence  Information Content     gene_id
# 0   270.313447             0.496543             8.247696  GFUI034947
# 1   529.038456             0.500000             5.471582  GFUI035874
# 2   307.758251             0.284597            13.424450  GFUI033625
# 3   159.513252             0.177063            10.153643  GFUI033625
# 4   184.352303             0.177063            11.734746  GFUI033625

# %% [markdown]
# #### Function to create dictionary-based retrieval object for gene/SNP data:

# %%
def snp_vs_gff_to_DF(bedtools_out):
    headers = ["bed3_seq",
               "bed3_start",
               "bed3_end",
               "gff3_seq",
               "gff3_source",
               "gff3_type",
               "gff3_start",
               "gff3_end",
               "gff3_score",
               "gff3_strand",
               "gff3_phase",
               "gff3_attributes",]
    df = pd.read_csv(bedtools_out.fn, sep='\t', names=headers)
    
    gene_id = lambda x: parse_gff3_attributes(x)['ID']
    
    df['gff3_rec'] = df.gff3_attributes.apply(gene_id)
    
    return df

def genes_near_bed(query_bedtool, gene_bedtool, annotations, w=1000):
    df = snp_vs_gff_to_DF(query_bedtool.window(gene_bedtool, w=w))
    df = df.merge(right=annotations,
                  how='left',
                  on=None,
                  left_on='gff3_rec', 
                  right_on='gene_id')
    return df

# %%
# - generate set of non-redundant andrea snps from joined table as set of tuples
# - convert to bedtool object(s)
def reduce_joined_SNP_coords(snps_interest_df):
    df = snps_interest_df  # less typing

    if len(df) == 0:
        return None
    
    
    snp_set = set()
    snp_set.update(list(df.apply(lambda x: str((x.seq_x, x.start_x, x.end_x)),1)))
    snp_set.update(list(df.apply(lambda x: str((x.seq_y, x.start_y, x.end_y)),1)))

    snp_set.discard("(nan, nan, nan)")
    
    return pbt.BedTool('\n'.join((l.replace(".0",'').replace("'","").replace('(','').replace(')','').replace(',','\t') for l in snp_set)), from_string=True)


# - get windowed intersection intersection with gene models using pybedtools

def get_win_isec(a,b,win=1000):
    if a is None:
        return None
    return a.window(b, w=win)


def add_SNP_to_gene_distance(df):
    if df is not None:
        df['d_to_gene'] = df.apply(d_to_gene,1)


def d_to_gene(x):

    low,high = ((x.bed3_end - x.gff3_start),(x.bed3_end - x.gff3_end))

    if (low >= 0) and (high <= 0):
        return 0
    else:
        return min([abs(low),abs(high)])

    

# get annotations for genes:
def join_genes_with_annos(genes, annotations, how="inner"):
    if genes is None:
        return None
    return pd.merge(left=genes, right=annotations, 
                    how=how, 
                    on=None, 
                    left_on='gff3_rec', right_on='gene_id')

# %%
def make_table_selected_snps_vs_LD_filter(anno_dfs):
    
    new_headers = ["SNP group",
                   "Gene",
                   "Scaffold",
                   "SNP Location",
                   "Distance to Gene",
                   "Top C",
                   "Top P",
                   "Top F"]

    old_headers = ["snp_group",
                   "bed3_seq",
                   "gff3_rec",
                   "bed3_end",
                   "d_to_gene"]


    
    concat_df = concat_dfs(anno_dfs)


    # group concat_df
    groups = concat_df.groupby(by=old_headers)

    # Collect row data
    out_rows = []

    for name,group in groups.groups.items():
        out_rows.append(new_row_from_group(groups.get_group(name)))

    # create final table
#     out_table = pd.DataFrame(data=out_rows, index=None, columns=new_headers, dtype=None, copy=False)
#     gene_mask = out_table.Gene.notnull()
#     out_table = out_table[gene_mask]
    return pd.DataFrame(data=out_rows, index=None, columns=new_headers, dtype=None, copy=False)



def new_row_from_group(group):

    row  = get_old_header_values(group)
    row["Top C"] = get_top_3_terms(group=group,aspect="C")
    row["Top P"] = get_top_3_terms(group=group,aspect="P")
    row["Top F"] = get_top_3_terms(group=group,aspect="F")

    return pd.Series(row)

def get_old_header_values(group):
    vals = munch.Munch()

    vals["SNP group"] = group.snp_group.iloc[0]
    vals["Scaffold"] = group.bed3_seq.iloc[0]
    vals["Gene"] = group.gff3_rec.iloc[0]
    vals["SNP Location"] = group.bed3_end.iloc[0]
    vals["Distance to Gene"] = group.d_to_gene.iloc[0]

    return vals


def get_top_3_terms(group,aspect):
    df = group.query("Aspect == '{aspect}'".format(aspect=aspect))

    return ";".join(df.sort("Total Score").Name[:3].values)

def concat_dfs(dfs):

    concat_df = pd.DataFrame()

    # add snp-group name to rows and concat to new table
    for name, df in dfs.items():

        try:
            df["snp_group"] = name
        except TypeError:
            pass

        concat_df = pd.concat(objs=[concat_df,df], axis=0, join='outer', join_axes=None, ignore_index=True, keys=None, levels=None, names=None, verify_integrity=False, copy=True)

    return concat_df

# %% [markdown]
# #  Genes located near by `query_bedtool`

# %%
NEARBY_GENES = {}
NEARBY_GENES['Top10_InfectionOverall'] = genes_near_bed(query_bedtool=Top10_InfectionOverall, gene_bedtool=genes, annotations=argot2_200)
NEARBY_GENES['Top10_corrected_PopPairwiseOverlap_Infection2015'] = genes_near_bed(query_bedtool=Top10_corrected_PopPairwiseOverlap_Infection2015, gene_bedtool=genes, annotations=argot2_200)
NEARBY_GENES['Top10_PopPairwiseOverlap_Environm'] = genes_near_bed(query_bedtool=Top10_PopPairwiseOverlap_Environm, gene_bedtool=genes, annotations=argot2_200)
NEARBY_GENES['Selected_PopPairwiseMSOT_Environm'] = genes_near_bed(query_bedtool=Selected_PopPairwiseMSOT_Environm, gene_bedtool=genes, annotations=argot2_200)
NEARBY_GENES['Selected_PopPairwiseMSNB_Environm'] = genes_near_bed(query_bedtool=Selected_PopPairwiseMSNB_Environm, gene_bedtool=genes, annotations=argot2_200)
NEARBY_GENES['pcadapt_outliers'] = genes_near_bed(query_bedtool=pcadapt_outliers, gene_bedtool=genes, annotations=argot2_200)

# %%
NEARBY_GENES['Top10_InfectionOverall'].head()
# Out:
#       bed3_seq  bed3_start  bed3_end     gff3_seq gff3_source gff3_type  \
# 0  Scaffold997       26216     26217  Scaffold997  VectorBase      gene
# 1  Scaffold997       26216     26217  Scaffold997  VectorBase      gene
# 2  Scaffold997       26216     26217  Scaffold997  VectorBase      gene
# 3  Scaffold997       26216     26217  Scaffold997  VectorBase      gene
# 4  Scaffold178      270329    270330  Scaffold178  VectorBase      gene
#
#    gff3_start  gff3_end gff3_score gff3_strand gff3_phase  \
# 0       26889     27995          .           +          .
# 1       26282     37306          .           -          .
# 2       26282     37306          .           -          .
# 3       26282     37306          .           -          .
# 4      262743    272422          .           +          .
#
#                         gff3_attributes    gff3_rec       Sequence Aspect  \
# 0  ID=GFUI053062;biotype=protein_coding  GFUI053062            NaN    NaN
# 1  ID=GFUI053061;biotype=protein_coding  GFUI053061  GFUI053061-PA      F
# 2  ID=GFUI053061;biotype=protein_coding  GFUI053061  GFUI053061-PA      F
# 3  ID=GFUI053061;biotype=protein_coding  GFUI053061  GFUI053061-PA      C
# 4  ID=GFUI012103;biotype=protein_coding  GFUI012103  GFUI012103-PA      P
#
#         GO ID                                        Name  Total Score  \
# 0         NaN                                         NaN          NaN
# 1  GO:0004857                   enzyme inhibitor activity  1816.136539
# 2  GO:0008073  ornithine decarboxylase inhibitor activity  7212.195844
# 3  GO:0005634                                     nucleus   410.272614
# 4  GO:0006355  regulation of transcription, DNA-templated   814.617216
#
#    Internal Confidence  Information Content     gene_id
# 0                  NaN                  NaN         NaN
# 1             0.768022             8.160737  GFUI053061
# 2             0.467692            13.363628  GFUI053061
# 3             0.296264             5.725783  GFUI053061
# 4             0.325480             7.524266  GFUI012103

# %%
for name, value in NEARBY_GENES.items():
        if value is None:
            pass
        elif (len(value) > 0):
            add_SNP_to_gene_distance(value)
        else:
            NEARBY_GENES[name] = None

# %%
table1 = make_table_selected_snps_vs_LD_filter(NEARBY_GENES)

# %%
table1[table1["SNP group"] == "Top10_PopPairwiseOverlap_Environm"]
# Out:
#                               SNP group        Gene      Scaffold  \
# 24    Top10_PopPairwiseOverlap_Environm  GFUI033690    Scaffold44
# 38    Top10_PopPairwiseOverlap_Environm  GFUI034289   Scaffold462
# 41    Top10_PopPairwiseOverlap_Environm  GFUI004681   Scaffold117
# 47    Top10_PopPairwiseOverlap_Environm  GFUI004309  Scaffold1143
# 52    Top10_PopPairwiseOverlap_Environm  GFUI020054   Scaffold259
# 56    Top10_PopPairwiseOverlap_Environm  GFUI028322   Scaffold366
# 64    Top10_PopPairwiseOverlap_Environm  GFUI007034   Scaffold133
# 71    Top10_PopPairwiseOverlap_Environm  GFUI042223   Scaffold629
# 74    Top10_PopPairwiseOverlap_Environm  GFUI002964   Scaffold106
# 82    Top10_PopPairwiseOverlap_Environm  GFUI002026   Scaffold101
# 88    Top10_PopPairwiseOverlap_Environm  GFUI030827     Scaffold3
# 101   Top10_PopPairwiseOverlap_Environm  GFUI039275    Scaffold55
# 103   Top10_PopPairwiseOverlap_Environm  GFUI013846   Scaffold193
# 152   Top10_PopPairwiseOverlap_Environm  GFUI034289   Scaffold462
# 170   Top10_PopPairwiseOverlap_Environm  GFUI002577   Scaffold104
# 172   Top10_PopPairwiseOverlap_Environm  GFUI033815   Scaffold452
# 182   Top10_PopPairwiseOverlap_Environm  GFUI042920    Scaffold64
# 217   Top10_PopPairwiseOverlap_Environm  GFUI045248   Scaffold705
# 230   Top10_PopPairwiseOverlap_Environm  GFUI034473   Scaffold467
# 234   Top10_PopPairwiseOverlap_Environm  GFUI005535  Scaffold1229
# 308   Top10_PopPairwiseOverlap_Environm  GFUI032150   Scaffold422
# 315   Top10_PopPairwiseOverlap_Environm  GFUI034755   Scaffold471
# 327   Top10_PopPairwiseOverlap_Environm  GFUI026687    Scaffold33
# 329   Top10_PopPairwiseOverlap_Environm  GFUI014310   Scaffold199
# 344   Top10_PopPairwiseOverlap_Environm  GFUI018366   Scaffold238
# 362   Top10_PopPairwiseOverlap_Environm  GFUI022915   Scaffold293
# 387   Top10_PopPairwiseOverlap_Environm  GFUI050797    Scaffold89
# 392   Top10_PopPairwiseOverlap_Environm  GFUI035173    Scaffold47
# 403   Top10_PopPairwiseOverlap_Environm  GFUI038587   Scaffold543
# 424   Top10_PopPairwiseOverlap_Environm  GFUI020973    Scaffold26
# ...                                 ...         ...           ...
# 5210  Top10_PopPairwiseOverlap_Environm  GFUI028984   Scaffold375
# 5220  Top10_PopPairwiseOverlap_Environm  GFUI040295   Scaffold584
# 5228  Top10_PopPairwiseOverlap_Environm  GFUI051764   Scaffold927
# 5236  Top10_PopPairwiseOverlap_Environm  GFUI019281   Scaffold249
# 5249  Top10_PopPairwiseOverlap_Environm  GFUI004545  Scaffold1168
# 5259  Top10_PopPairwiseOverlap_Environm  GFUI035316   Scaffold480
# 5298  Top10_PopPairwiseOverlap_Environm  GFUI028865   Scaffold373
# 5300  Top10_PopPairwiseOverlap_Environm  GFUI007758    Scaffold13
# 5305  Top10_PopPairwiseOverlap_Environm  GFUI030791     Scaffold3
# 5311  Top10_PopPairwiseOverlap_Environm  GFUI013068   Scaffold186
# 5328  Top10_PopPairwiseOverlap_Environm  GFUI031574   Scaffold412
# 5343  Top10_PopPairwiseOverlap_Environm  GFUI002090   Scaffold101
# 5363  Top10_PopPairwiseOverlap_Environm  GFUI032156   Scaffold422
# 5383  Top10_PopPairwiseOverlap_Environm  GFUI046107   Scaffold730
# 5475  Top10_PopPairwiseOverlap_Environm  GFUI030130   Scaffold394
# 5477  Top10_PopPairwiseOverlap_Environm  GFUI019732   Scaffold253
# 5479  Top10_PopPairwiseOverlap_Environm  GFUI027610   Scaffold355
# 5483  Top10_PopPairwiseOverlap_Environm  GFUI043585   Scaffold669
# 5523  Top10_PopPairwiseOverlap_Environm  GFUI035931   Scaffold494
# 5530  Top10_PopPairwiseOverlap_Environm  GFUI039963   Scaffold577
# 5536  Top10_PopPairwiseOverlap_Environm  GFUI030478     Scaffold3
# 5557  Top10_PopPairwiseOverlap_Environm  GFUI034836   Scaffold473
# 5558  Top10_PopPairwiseOverlap_Environm  GFUI034760   Scaffold471
# 5574  Top10_PopPairwiseOverlap_Environm  GFUI015986   Scaffold210
# 5617  Top10_PopPairwiseOverlap_Environm  GFUI045926   Scaffold729
# 5639  Top10_PopPairwiseOverlap_Environm  GFUI036939   Scaffold508
# 5658  Top10_PopPairwiseOverlap_Environm  GFUI046447   Scaffold740
# 5659  Top10_PopPairwiseOverlap_Environm  GFUI051764   Scaffold927
# 5672  Top10_PopPairwiseOverlap_Environm  GFUI028983   Scaffold375
# 5695  Top10_PopPairwiseOverlap_Environm  GFUI044514   Scaffold693
#
#       SNP Location  Distance to Gene  \
# 24          987351               600
# 38          241848                 0
# 41          218733                 0
# 47           13111                 0
# 52             225                 0
# 56           11482                 0
# 64          246276                 0
# 71           27347                 0
# 74          700347                 0
# 82          167731                 0
# 88         2235216                 0
# 101         829694                 0
# 103         338581               664
# 152         241892                 0
# 170         401097               538
# 172         133597               407
# 182          66699                 0
# 217          16364                 0
# 230         181703                 0
# 234           1373                 0
# 308          60574               896
# 315         223064                 0
# 327        1392625                 0
# 329         506529                 0
# 344         238330                 0
# 362         280009               452
# 387         627276                 0
# 392         333172                 0
# 403         245735                 0
# 424         784654               444
# ...            ...               ...
# 5210        276957                 0
# 5220         66923                 0
# 5228         11462                 0
# 5236        119747                66
# 5249         13825                 0
# 5259        149488                 0
# 5298         44406                 0
# 5300        663215               922
# 5305       2016447                 0
# 5311        240058               617
# 5328         54747                 0
# 5343        517394                 0
# 5363         60512                 0
# 5383         54980                 0
# 5475        196971                 0
# 5477        242396                 0
# 5479         64477                 0
# 5483        128587                 0
# 5523         55028                 0
# 5530        182680               903
# 5536         46899                 0
# 5557        150425                 0
# 5558        160003                 0
# 5574        477927                 0
# 5617         43987                 0
# 5639        182564                 0
# 5658         14312                 0
# 5659         11444                 0
# 5672        276934               939
# 5695         11395                 0
#
#                                                   Top C  \
# 24
# 38
# 41
# 47
# 52                    plasma membrane;cytoplasm;nucleus
# 56
# 64                                              nucleus
# 71
# 74
# 82
# 88                                              nucleus
# 101             membrane;integral component of membrane
# 103
# 152
# 170
# 172
# 182
# 217                                             nucleus
# 230
# 234                                       mitochondrion
# 308
# 315
# 327                            cytoplasm;myosin complex
# 329                                extracellular region
# 344
# 362
# 387
# 392
# 403
# 424   cytoplasm;intracellular membrane-bounded organ...
# ...                                                 ...
# 5210
# 5220
# 5228      mitochondrion;extracellular vesicular exosome
# 5236
# 5249
# 5259
# 5298  membrane;integral component of membrane;endopl...
# 5300            protein complex;intracellular;cytoplasm
# 5305  trans-Golgi network;Golgi cisterna membrane;me...
# 5311
# 5328                     integral component of membrane
# 5343
# 5363
# 5383
# 5475  cytoplasm;extracellular region;proteinaceous e...
# 5477
# 5479
# 5483
# 5523
# 5530
# 5536
# 5557
# 5558
# 5574                               extracellular region
# 5617
# 5639                        cytoplasm;cytoplasm;nucleus
# 5658  organelle membrane;membrane;endoplasmic reticulum
# 5659      mitochondrion;extracellular vesicular exosome
# 5672
# 5695
#
#                                                   Top P  \
# 24
# 38
# 41
# 47
# 52    apoptotic process;cell cycle;mitotic DNA repli...
# 56
# 64                         transcription, DNA-templated
# 71
# 74
# 82
# 88
# 101                                           transport
# 103
# 152
# 170
# 172
# 182
# 217
# 230
# 234
# 308
# 315
# 327
# 329                                   metabolic process
# 344
# 362
# 387
# 392
# 403
# 424   positive regulation of mRNA catabolic process;...
# ...                                                 ...
# 5210
# 5220
# 5228                                  metabolic process
# 5236
# 5249
# 5259
# 5298  protein glycosylation;protein N-linked glycosy...
# 5300  positive regulation of transcription from RNA ...
# 5305  transport;positive regulation of protein secre...
# 5311
# 5328
# 5343
# 5363
# 5383
# 5475                              Wnt signaling pathway
# 5477
# 5479
# 5483
# 5523
# 5530
# 5536
# 5557
# 5558
# 5574
# 5617
# 5639
# 5658
# 5659                                  metabolic process
# 5672
# 5695                        protein homooligomerization
#
#                                                   Top F LD Filtered
# 24                              ATP binding;ATP binding        True
# 38                                                              NaN
# 41                                                              NaN
# 47                                                              NaN
# 52    protein binding;protein heterodimerization act...         NaN
# 56                                                              NaN
# 64                                                              NaN
# 71                                                              NaN
# 74                                                              NaN
# 82                                                              NaN
# 88                                                             True
# 101      nucleotide binding;ATP binding;ATPase activity         NaN
# 103                                                             NaN
# 152                                                             NaN
# 170                                                             NaN
# 172                                                             NaN
# 182                                                             NaN
# 217   hydrolase activity, hydrolyzing O-glycosyl com...         NaN
# 230                                                             NaN
# 234                                         ATP binding         NaN
# 308                                                             NaN
# 315                                                             NaN
# 327        nucleotide binding;actin binding;ATP binding         NaN
# 329                                   lysozyme activity         NaN
# 344                                         DNA binding         NaN
# 362                                                             NaN
# 387                                                             NaN
# 392                                                             NaN
# 403                                                             NaN
# 424      nucleotide binding;GTP binding;GTPase activity         NaN
# ...                                                 ...         ...
# 5210                                                            NaN
# 5220                                                            NaN
# 5228        hydrolase activity;acylphosphatase activity         NaN
# 5236                                                            NaN
# 5249                                                            NaN
# 5259                                                            NaN
# 5298  transferase activity, transferring glycosyl gr...         NaN
# 5300                                        DNA binding         NaN
# 5305    Rab GTPase binding;enzyme binding;lipid binding         NaN
# 5311                                                            NaN
# 5328                                                            NaN
# 5343                                                            NaN
# 5363                                                            NaN
# 5383                                                           True
# 5475                  frizzled binding;receptor binding        True
# 5477                                                            NaN
# 5479                                        DNA binding         NaN
# 5483                                                            NaN
# 5523                                                            NaN
# 5530                                                            NaN
# 5536                                                            NaN
# 5557                                                           True
# 5558                                                            NaN
# 5574                                                            NaN
# 5617                                                            NaN
# 5639                                                            NaN
# 5658  metal ion binding;iron ion binding;oxidoreduct...         NaN
# 5659        hydrolase activity;acylphosphatase activity         NaN
# 5672               hydrolase activity;helicase activity         NaN
# 5695                                    ankyrin binding         NaN
#
# [380 rows x 9 columns]

# %%
# convert LD filtered SNP-pairs into table of single seq:location data

ld_snp_pairs = ld.query("one_minus_cdf_BH <= 0.01")
ld_snps_a = ld_snp_pairs[["CHR_A","BP_A"]].rename(columns={"CHR_A":"Scaffold","BP_A":"SNP Location"})
ld_snps_b = ld_snp_pairs[["CHR_A","BP_B"]].rename(columns={"CHR_A":"Scaffold","BP_B":"SNP Location"})
ld_snps = pd.concat([ld_snps_a,ld_snps_b]).sort()
ld_snps["LD Filtered"] = 'True'
ld_snps.head()
# Out:
#      Scaffold  SNP Location LD Filtered
# 11  Scaffold0         13388        True
# 11  Scaffold0         86267        True
# 21  Scaffold0        183680        True
# 21  Scaffold0         13388        True
# 84  Scaffold0         13388        True

# %%
table1 = table1.merge(ld_snps, 
             how='left', 
             on=["Scaffold","SNP Location"], left_on=None, right_on=None,  
             sort=False, suffixes=('_x', '_y'), copy=True).drop_duplicates()

# %%
# table1.to_excel('/home/gus/src/repos/git/markdown-docs/manuscripts/Gloria-Soria/2015/ddRAD58/tables/report_to_andrea_to_authors_PREFORMAT.xls',index=False)

# %%
table1.query()
# Out:
#                 SNP group        Gene     Scaffold  SNP Location  \
# 0  Top10_InfectionOverall  GFUI018116  Scaffold234        389179
# 1  Top10_InfectionOverall  GFUI017925  Scaffold232         57803
# 2  Top10_InfectionOverall  GFUI011116  Scaffold169         97127
# 3  Top10_InfectionOverall  GFUI035172   Scaffold47        317650
# 4  Top10_InfectionOverall  GFUI045207  Scaffold703         19953
#
#    Distance to Gene Top C                   Top P  \
# 0                 0        protein ubiquitination
# 1               478
# 2                 0
# 3                 0
# 4                 0                   proteolysis
#
#                                      Top F LD Filtered
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4  hydrolase activity;dipeptidase activity         NaN

# %% [markdown]
# # Overlap between top 10 infect and geographical

# %%
env10 = NEARBY_GENES['Top10_PopPairwiseOverlap_Environm']
inf10 = NEARBY_GENES['Top10_corrected_PopPairwiseOverlap_Infection2015']
inf10.head()
# Out:
#       bed3_seq  bed3_start  bed3_end     gff3_seq gff3_source gff3_type  \
# 0    Scaffold2     2593208   2593209    Scaffold2  VectorBase      gene
# 1  Scaffold355      306767    306768  Scaffold355  VectorBase      gene
# 2  Scaffold163      513433    513434  Scaffold163  VectorBase      gene
# 3  Scaffold163      513433    513434  Scaffold163  VectorBase      gene
# 4  Scaffold873       18833     18834  Scaffold873  VectorBase      gene
#
#    gff3_start  gff3_end gff3_score gff3_strand gff3_phase  \
# 0     2593175   2594101          .           -          .
# 1      287768    311543          .           -          .
# 2      513883    527197          .           -          .
# 3      513883    527197          .           -          .
# 4       11605     18148          .           +          .
#
#                         gff3_attributes    gff3_rec       Sequence Aspect  \
# 0  ID=GFUI023810;biotype=protein_coding  GFUI023810            NaN    NaN
# 1  ID=GFUI027633;biotype=protein_coding  GFUI027633            NaN    NaN
# 2  ID=GFUI010652;biotype=protein_coding  GFUI010652  GFUI010652-PA      P
# 3  ID=GFUI010652;biotype=protein_coding  GFUI010652  GFUI010652-PA      C
# 4  ID=GFUI050068;biotype=protein_coding  GFUI050068            NaN    NaN
#
#         GO ID                   Name  Total Score  Internal Confidence  \
# 0         NaN                    NaN          NaN                  NaN
# 1         NaN                    NaN          NaN                  NaN
# 2  GO:0006200  ATP catabolic process   474.917555             0.939484
# 3  GO:0019028           viral capsid  1239.312392             1.000000
# 4         NaN                    NaN          NaN                  NaN
#
#    Information Content     gene_id  d_to_gene  \
# 0                  NaN         NaN          0
# 1                  NaN         NaN          0
# 2             8.421864  GFUI010652        449
# 3             6.609099  GFUI010652        449
# 4                  NaN         NaN        686
#
#                                           snp_group
# 0  Top10_corrected_PopPairwiseOverlap_Infection2015
# 1  Top10_corrected_PopPairwiseOverlap_Infection2015
# 2  Top10_corrected_PopPairwiseOverlap_Infection2015
# 3  Top10_corrected_PopPairwiseOverlap_Infection2015
# 4  Top10_corrected_PopPairwiseOverlap_Infection2015

# %%
env_inf = env10.merge(right=inf10, 
                    how='inner',
                    on=["bed3_seq","bed3_start","bed3_end"], left_on=None, right_on=None,
                    left_index=False, right_index=False,
                    sort=False, suffixes=('_x', '_y'),
                    copy=True)

# %%
env_inf
# Out:
# Empty DataFrame
# Columns: [bed3_seq, bed3_start, bed3_end, gff3_seq_x, gff3_source_x, gff3_type_x, gff3_start_x, gff3_end_x, gff3_score_x, gff3_strand_x, gff3_phase_x, gff3_attributes_x, gff3_rec_x, Sequence_x, Aspect_x, GO ID_x, Name_x, Total Score_x, Internal Confidence_x, Information Content_x, gene_id_x, d_to_gene_x, snp_group_x, gff3_seq_y, gff3_source_y, gff3_type_y, gff3_start_y, gff3_end_y, gff3_score_y, gff3_strand_y, gff3_phase_y, gff3_attributes_y, gff3_rec_y, Sequence_y, Aspect_y, GO ID_y, Name_y, Total Score_y, Internal Confidence_y, Information Content_y, gene_id_y, d_to_gene_y, snp_group_y]
# Index: []

# %%
env10_set = set(env10.bed3_end)
inf10_set = set(inf10.bed3_end)

# %%
env10_set.intersection(inf10_set)
# Out:
# set()

# %%
inf10.query("gff3_rec == 'GFUI009292'")
# Out:
# Empty DataFrame
# Columns: [bed3_seq, bed3_start, bed3_end, gff3_seq, gff3_source, gff3_type, gff3_start, gff3_end, gff3_score, gff3_strand, gff3_phase, gff3_attributes, gff3_rec, Sequence, Aspect, GO ID, Name, Total Score, Internal Confidence, Information Content, gene_id, d_to_gene, snp_group]
# Index: []
