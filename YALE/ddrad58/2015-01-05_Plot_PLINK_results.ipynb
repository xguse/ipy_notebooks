# %% [markdown]
# # Purpose:
#
# 2015-01-05
#
# - Plot results from `plink`-based LD analysis to help visualize possible areas of interest.
# - should probably cross-reference areas identified using `hapFLK` by Andrea as well.

# %% [markdown]
# # Implementation:

# %% [markdown]
# ## Imports:

# %%
# plotting imports
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
# import tables as h5

# %% [markdown]
# ## File paths:

# %%
# define paths to files
ld_table = "/home/gus/remote_mounts/louise/data/genomes/glossina_fuscipes/annotations/SNPs/plink_out/tsetseFINAL_14Oct2014_f2_53.recode.renamed_scaffolds.maf0_05.vcf/ld/r_none_freqs_dprime.ld"

LD_22 = "/home/gus/remote_mounts/louise/data/dummy_datasets/linkage_diseq/hapmap/ld_chr22_MEX.txt"

# %%
ld = pd.read_table(ld_table, sep=" +")
# Out:
# /home/gus/.virtualenvs/py279/lib/python2.7/site-packages/pandas/io/parsers.py:639: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
ld.head()
# Out:
#        CHR_A   BP_A SNP_A     MAF_A      CHR_B   BP_B SNP_B     MAF_B  \
# 0  Scaffold0  13388     .  0.278846  Scaffold0  23408     .  0.298077
# 1  Scaffold0  13388     .  0.278846  Scaffold0  23418     .  0.298077
# 2  Scaffold0  13388     .  0.278846  Scaffold0  23421     .  0.298077
# 3  Scaffold0  13388     .  0.278846  Scaffold0  23431     .  0.288462
# 4  Scaffold0  13388     .  0.278846  Scaffold0  30544     .  0.094340
#
#           R  DP
# 0  1.000000   1
# 1  1.000000   1
# 2  1.000000   1
# 3  0.975946   1
# 4  0.464238   1

# %%
ld[ld.CHR_A == 'Scaffold340'].head()
# Out:
#               CHR_A   BP_A SNP_A    MAF_A        CHR_B   BP_B SNP_B     MAF_B  \
# 222731  Scaffold340  19944     .  0.09375  Scaffold340  25404     .  0.240000
# 222732  Scaffold340  19944     .  0.09375  Scaffold340  26398     .  0.226415
# 222733  Scaffold340  19944     .  0.09375  Scaffold340  26413     .  0.150943
# 222734  Scaffold340  19944     .  0.09375  Scaffold340  26436     .  0.132075
# 222735  Scaffold340  19944     .  0.09375  Scaffold340  26440     .  0.122642
#
#                R        DP
# 222731 -0.188353  1.000000
# 222732  0.510701  0.840203
# 222733 -0.143839  1.000000
# 222734 -0.132898  1.000000
# 222735 -0.127290  1.000000

# %%
sorted(set(ld.CHR_A))
# Out:
# ['JFJR01006593.1',
#  'JFJR01008464.1',
#  'JFJR01008577.1',
#  'JFJR01008756.1',
#  'JFJR01009309.1',
#  'JFJR01009825.1',
#  'JFJR01010034.1',
#  'JFJR01010145.1',
#  'JFJR01010159.1',
#  'JFJR01010160.1',
#  'JFJR01010254.1',
#  'JFJR01010337.1',
#  'JFJR01010431.1',
#  'JFJR01010659.1',
#  'JFJR01010668.1',
#  'JFJR01010779.1',
#  'JFJR01010910.1',
#  'JFJR01010963.1',
#  'JFJR01010968.1',
#  'JFJR01011023.1',
#  'JFJR01011090.1',
#  'JFJR01011182.1',
#  'JFJR01011458.1',
#  'JFJR01011479.1',
#  'JFJR01011729.1',
#  'JFJR01011756.1',
#  'JFJR01011881.1',
#  'JFJR01012081.1',
#  'JFJR01012306.1',
#  'JFJR01012325.1',
#  'JFJR01012337.1',
#  'JFJR01012340.1',
#  'JFJR01012364.1',
#  'JFJR01012369.1',
#  'JFJR01012395.1',
#  'JFJR01012480.1',
#  'JFJR01012489.1',
#  'JFJR01012546.1',
#  'JFJR01012582.1',
#  'JFJR01012660.1',
#  'JFJR01012674.1',
#  'JFJR01012681.1',
#  'JFJR01012682.1',
#  'JFJR01012687.1',
#  'JFJR01012697.1',
#  'JFJR01012701.1',
#  'JFJR01012705.1',
#  'JFJR01012707.1',
#  'JFJR01012711.1',
#  'JFJR01012719.1',
#  'JFJR01012723.1',
#  'JFJR01012730.1',
#  'JFJR01012732.1',
#  'JFJR01012733.1',
#  'JFJR01012735.1',
#  'JFJR01012745.1',
#  'JFJR01012749.1',
#  'JFJR01012763.1',
#  'JFJR01012778.1',
#  'JFJR01012779.1',
#  'JFJR01012790.1',
#  'JFJR01012796.1',
#  'JFJR01012811.1',
#  'JFJR01012812.1',
#  'JFJR01012813.1',
#  'JFJR01012814.1',
#  'JFJR01012815.1',
#  'JFJR01012817.1',
#  'JFJR01012818.1',
#  'JFJR01012819.1',
#  'JFJR01012820.1',
#  'JFJR01012821.1',
#  'JFJR01012823.1',
#  'JFJR01012824.1',
#  'JFJR01012825.1',
#  'JFJR01012826.1',
#  'JFJR01012827.1',
#  'JFJR01012831.1',
#  'JFJR01012832.1',
#  'JFJR01012833.1',
#  'JFJR01012835.1',
#  'JFJR01012837.1',
#  'JFJR01012838.1',
#  'JFJR01012839.1',
#  'JFJR01012842.1',
#  'JFJR01012844.1',
#  'JFJR01012847.1',
#  'JFJR01012850.1',
#  'JFJR01012852.1',
#  'JFJR01012855.1',
#  'JFJR01012857.1',
#  'JFJR01012862.1',
#  'JFJR01012868.1',
#  'JFJR01012881.1',
#  'JFJR01012884.1',
#  'JFJR01012888.1',
#  'JFJR01012891.1',
#  'JFJR01012900.1',
#  'JFJR01012904.1',
#  'JFJR01012920.1',
#  'JFJR01012925.1',
#  'JFJR01012926.1',
#  'JFJR01012928.1',
#  'JFJR01012937.1',
#  'JFJR01012946.1',
#  'JFJR01012950.1',
#  'JFJR01012957.1',
#  'JFJR01012971.1',
#  'JFJR01013015.1',
#  'JFJR01013065.1',
#  'JFJR01013081.1',
#  'JFJR01013095.1',
#  'JFJR01013101.1',
#  'JFJR01013128.1',
#  'JFJR01013140.1',
#  'JFJR01013186.1',
#  'JFJR01013219.1',
#  'JFJR01013226.1',
#  'JFJR01013235.1',
#  'JFJR01013266.1',
#  'JFJR01013309.1',
#  'JFJR01013318.1',
#  'JFJR01013319.1',
#  'JFJR01013328.1',
#  'JFJR01013381.1',
#  'JFJR01013387.1',
#  'JFJR01013439.1',
#  'JFJR01013500.1',
#  'JFJR01013507.1',
#  'JFJR01013508.1',
#  'JFJR01013535.1',
#  'JFJR01013546.1',
#  'Scaffold0',
#  'Scaffold1',
#  'Scaffold10',
#  'Scaffold100',
#  'Scaffold1001',
#  'Scaffold1002',
#  'Scaffold1003',
#  'Scaffold1004',
#  'Scaffold1007',
#  'Scaffold1009',
#  'Scaffold101',
#  'Scaffold1010',
#  'Scaffold1011',
#  'Scaffold1012',
#  'Scaffold1013',
#  'Scaffold1014',
#  'Scaffold1015',
#  'Scaffold1016',
#  'Scaffold1017',
#  'Scaffold1019',
#  'Scaffold102',
#  'Scaffold1020',
#  'Scaffold1021',
#  'Scaffold1022',
#  'Scaffold1023',
#  'Scaffold1024',
#  'Scaffold1025',
#  'Scaffold1026',
#  'Scaffold1028',
#  'Scaffold1029',
#  'Scaffold103',
#  'Scaffold1030',
#  'Scaffold1031',
#  'Scaffold1033',
#  'Scaffold1034',
#  'Scaffold1035',
#  'Scaffold1036',
#  'Scaffold1037',
#  'Scaffold1038',
#  'Scaffold1039',
#  'Scaffold104',
#  'Scaffold1040',
#  'Scaffold1042',
#  'Scaffold1043',
#  'Scaffold1045',
#  'Scaffold1046',
#  'Scaffold105',
#  'Scaffold1050',
#  'Scaffold1051',
#  'Scaffold1056',
#  'Scaffold1058',
#  'Scaffold1059',
#  'Scaffold106',
#  'Scaffold1060',
#  'Scaffold1061',
#  'Scaffold1064',
#  'Scaffold1065',
#  'Scaffold1066',
#  'Scaffold1067',
#  'Scaffold1068',
#  'Scaffold1069',
#  'Scaffold107',
#  'Scaffold1072',
#  'Scaffold1078',
#  'Scaffold1079',
#  'Scaffold108',
#  'Scaffold1080',
#  'Scaffold1082',
#  'Scaffold1085',
#  'Scaffold1086',
#  'Scaffold1087',
#  'Scaffold1088',
#  'Scaffold1089',
#  'Scaffold109',
#  'Scaffold1091',
#  'Scaffold1093',
#  'Scaffold1095',
#  'Scaffold1097',
#  'Scaffold1098',
#  'Scaffold11',
#  'Scaffold110',
#  'Scaffold1100',
#  'Scaffold1101',
#  'Scaffold1103',
#  'Scaffold1104',
#  'Scaffold1107',
#  'Scaffold1109',
#  'Scaffold111',
#  'Scaffold1110',
#  'Scaffold1111',
#  'Scaffold1112',
#  'Scaffold1113',
#  'Scaffold1115',
#  'Scaffold1116',
#  'Scaffold1118',
#  'Scaffold112',
#  'Scaffold1121',
#  'Scaffold1122',
#  'Scaffold1124',
#  'Scaffold1125',
#  'Scaffold1126',
#  'Scaffold1129',
#  'Scaffold113',
#  'Scaffold1131',
#  'Scaffold1132',
#  'Scaffold1133',
#  'Scaffold1134',
#  'Scaffold1135',
#  'Scaffold1136',
#  'Scaffold1137',
#  'Scaffold1138',
#  'Scaffold1139',
#  'Scaffold114',
#  'Scaffold1140',
#  'Scaffold1142',
#  'Scaffold1143',
#  'Scaffold1147',
#  'Scaffold1149',
#  'Scaffold115',
#  'Scaffold1150',
#  'Scaffold1156',
#  'Scaffold1157',
#  'Scaffold1158',
#  'Scaffold1159',
#  'Scaffold116',
#  'Scaffold1163',
#  'Scaffold1165',
#  'Scaffold1166',
#  'Scaffold1168',
#  'Scaffold1169',
#  'Scaffold117',
#  'Scaffold1170',
#  'Scaffold1171',
#  'Scaffold1173',
#  'Scaffold1174',
#  'Scaffold1175',
#  'Scaffold1176',
#  'Scaffold118',
#  'Scaffold1181',
#  'Scaffold1186',
#  'Scaffold1189',
#  'Scaffold119',
#  'Scaffold1190',
#  'Scaffold1193',
#  'Scaffold1196',
#  'Scaffold1198',
#  'Scaffold1199',
#  'Scaffold12',
#  'Scaffold120',
#  'Scaffold1204',
#  'Scaffold1209',
#  'Scaffold121',
#  'Scaffold1211',
#  'Scaffold1212',
#  'Scaffold1213',
#  'Scaffold1214',
#  'Scaffold1215',
#  'Scaffold1218',
#  'Scaffold1219',
#  'Scaffold122',
#  'Scaffold1221',
#  'Scaffold1224',
#  'Scaffold1228',
#  'Scaffold1229',
#  'Scaffold123',
#  'Scaffold1230',
#  'Scaffold1232',
#  'Scaffold1233',
#  'Scaffold1234',
#  'Scaffold1237',
#  'Scaffold1238',
#  'Scaffold124',
#  'Scaffold1240',
#  'Scaffold1241',
#  'Scaffold1242',
#  'Scaffold1245',
#  'Scaffold1246',
#  'Scaffold1247',
#  'Scaffold1248',
#  'Scaffold125',
#  'Scaffold1251',
#  'Scaffold1252',
#  'Scaffold126',
#  'Scaffold1261',
#  'Scaffold1262',
#  'Scaffold1265',
#  'Scaffold127',
#  'Scaffold1270',
#  'Scaffold1272',
#  'Scaffold1274',
#  'Scaffold1275',
#  'Scaffold1276',
#  'Scaffold1277',
#  'Scaffold128',
#  'Scaffold1282',
#  'Scaffold1285',
#  'Scaffold129',
#  'Scaffold1293',
#  'Scaffold13',
#  'Scaffold130',
#  'Scaffold1301',
#  'Scaffold1303',
#  'Scaffold1305',
#  'Scaffold131',
#  'Scaffold1319',
#  'Scaffold132',
#  'Scaffold1324',
#  'Scaffold1325',
#  'Scaffold1326',
#  'Scaffold133',
#  'Scaffold1333',
#  'Scaffold1335',
#  'Scaffold134',
#  'Scaffold1345',
#  'Scaffold1347',
#  'Scaffold1349',
#  'Scaffold135',
#  'Scaffold1350',
#  'Scaffold1353',
#  'Scaffold1356',
#  'Scaffold1358',
#  'Scaffold136',
#  'Scaffold1361',
#  'Scaffold1363',
#  'Scaffold137',
#  'Scaffold138',
#  'Scaffold1381',
#  'Scaffold1382',
#  'Scaffold1383',
#  'Scaffold1385',
#  'Scaffold139',
#  'Scaffold1392',
#  'Scaffold14',
#  'Scaffold140',
#  'Scaffold1404',
#  'Scaffold1406',
#  'Scaffold141',
#  'Scaffold1412',
#  'Scaffold142',
#  'Scaffold1422',
#  'Scaffold143',
#  'Scaffold1430',
#  'Scaffold144',
#  'Scaffold1447',
#  'Scaffold145',
#  'Scaffold146',
#  'Scaffold147',
#  'Scaffold1470',
#  'Scaffold148',
#  'Scaffold149',
#  'Scaffold1494',
#  'Scaffold15',
#  'Scaffold150',
#  'Scaffold151',
#  'Scaffold152',
#  'Scaffold153',
#  'Scaffold154',
#  'Scaffold155',
#  'Scaffold156',
#  'Scaffold157',
#  'Scaffold158',
#  'Scaffold159',
#  'Scaffold16',
#  'Scaffold160',
#  'Scaffold161',
#  'Scaffold162',
#  'Scaffold163',
#  'Scaffold164',
#  'Scaffold165',
#  'Scaffold166',
#  'Scaffold167',
#  'Scaffold168',
#  'Scaffold169',
#  'Scaffold17',
#  'Scaffold170',
#  'Scaffold171',
#  'Scaffold172',
#  'Scaffold173',
#  'Scaffold174',
#  'Scaffold175',
#  'Scaffold176',
#  'Scaffold177',
#  'Scaffold178',
#  'Scaffold179',
#  'Scaffold18',
#  'Scaffold180',
#  'Scaffold181',
#  'Scaffold182',
#  'Scaffold183',
#  'Scaffold184',
#  'Scaffold185',
#  'Scaffold186',
#  'Scaffold187',
#  'Scaffold188',
#  'Scaffold189',
#  'Scaffold19',
#  'Scaffold190',
#  'Scaffold191',
#  'Scaffold192',
#  'Scaffold193',
#  'Scaffold194',
#  'Scaffold195',
#  'Scaffold196',
#  'Scaffold197',
#  'Scaffold198',
#  'Scaffold199',
#  'Scaffold2',
#  'Scaffold20',
#  'Scaffold200',
#  'Scaffold201',
#  'Scaffold202',
#  'Scaffold203',
#  'Scaffold204',
#  'Scaffold205',
#  'Scaffold206',
#  'Scaffold207',
#  'Scaffold208',
#  'Scaffold209',
#  'Scaffold21',
#  'Scaffold210',
#  'Scaffold211',
#  'Scaffold212',
#  'Scaffold214',
#  'Scaffold215',
#  'Scaffold216',
#  'Scaffold217',
#  'Scaffold218',
#  'Scaffold219',
#  'Scaffold22',
#  'Scaffold220',
#  'Scaffold221',
#  'Scaffold222',
#  'Scaffold223',
#  'Scaffold224',
#  'Scaffold225',
#  'Scaffold226',
#  'Scaffold227',
#  'Scaffold228',
#  'Scaffold229',
#  'Scaffold23',
#  'Scaffold230',
#  'Scaffold231',
#  'Scaffold232',
#  'Scaffold233',
#  'Scaffold234',
#  'Scaffold235',
#  'Scaffold236',
#  'Scaffold237',
#  'Scaffold238',
#  'Scaffold239',
#  'Scaffold24',
#  'Scaffold240',
#  'Scaffold241',
#  'Scaffold242',
#  'Scaffold243',
#  'Scaffold244',
#  'Scaffold245',
#  'Scaffold246',
#  'Scaffold247',
#  'Scaffold248',
#  'Scaffold249',
#  'Scaffold25',
#  'Scaffold250',
#  'Scaffold251',
#  'Scaffold252',
#  'Scaffold253',
#  'Scaffold254',
#  'Scaffold255',
#  'Scaffold256',
#  'Scaffold257',
#  'Scaffold258',
#  'Scaffold259',
#  'Scaffold26',
#  'Scaffold260',
#  'Scaffold261',
#  'Scaffold262',
#  'Scaffold263',
#  'Scaffold264',
#  'Scaffold265',
#  'Scaffold266',
#  'Scaffold267',
#  'Scaffold268',
#  'Scaffold269',
#  'Scaffold27',
#  'Scaffold270',
#  'Scaffold271',
#  'Scaffold272',
#  'Scaffold273',
#  'Scaffold274',
#  'Scaffold275',
#  'Scaffold276',
#  'Scaffold277',
#  'Scaffold278',
#  'Scaffold279',
#  'Scaffold28',
#  'Scaffold280',
#  'Scaffold281',
#  'Scaffold282',
#  'Scaffold283',
#  'Scaffold284',
#  'Scaffold285',
#  'Scaffold286',
#  'Scaffold287',
#  'Scaffold288',
#  'Scaffold289',
#  'Scaffold29',
#  'Scaffold290',
#  'Scaffold291',
#  'Scaffold292',
#  'Scaffold293',
#  'Scaffold294',
#  'Scaffold295',
#  'Scaffold296',
#  'Scaffold297',
#  'Scaffold298',
#  'Scaffold299',
#  'Scaffold3',
#  'Scaffold30',
#  'Scaffold300',
#  'Scaffold301',
#  'Scaffold302',
#  'Scaffold303',
#  'Scaffold304',
#  'Scaffold305',
#  'Scaffold306',
#  'Scaffold307',
#  'Scaffold308',
#  'Scaffold309',
#  'Scaffold31',
#  'Scaffold310',
#  'Scaffold311',
#  'Scaffold312',
#  'Scaffold313',
#  'Scaffold314',
#  'Scaffold315',
#  'Scaffold316',
#  'Scaffold317',
#  'Scaffold318',
#  'Scaffold319',
#  'Scaffold32',
#  'Scaffold320',
#  'Scaffold321',
#  'Scaffold322',
#  'Scaffold323',
#  'Scaffold324',
#  'Scaffold325',
#  'Scaffold327',
#  'Scaffold328',
#  'Scaffold329',
#  'Scaffold33',
#  'Scaffold330',
#  'Scaffold331',
#  'Scaffold332',
#  'Scaffold333',
#  'Scaffold334',
#  'Scaffold335',
#  'Scaffold336',
#  'Scaffold337',
#  'Scaffold338',
#  'Scaffold339',
#  'Scaffold34',
#  'Scaffold340',
#  'Scaffold341',
#  'Scaffold342',
#  'Scaffold343',
#  'Scaffold344',
#  'Scaffold345',
#  'Scaffold346',
#  'Scaffold347',
#  'Scaffold348',
#  'Scaffold349',
#  'Scaffold35',
#  'Scaffold350',
#  'Scaffold351',
#  'Scaffold352',
#  'Scaffold353',
#  'Scaffold354',
#  'Scaffold355',
#  'Scaffold356',
#  'Scaffold357',
#  'Scaffold358',
#  'Scaffold359',
#  'Scaffold36',
#  'Scaffold360',
#  'Scaffold361',
#  'Scaffold362',
#  'Scaffold363',
#  'Scaffold364',
#  'Scaffold365',
#  'Scaffold366',
#  'Scaffold367',
#  'Scaffold368',
#  'Scaffold369',
#  'Scaffold37',
#  'Scaffold370',
#  'Scaffold371',
#  'Scaffold372',
#  'Scaffold373',
#  'Scaffold374',
#  'Scaffold375',
#  'Scaffold376',
#  'Scaffold377',
#  'Scaffold378',
#  'Scaffold379',
#  'Scaffold38',
#  'Scaffold380',
#  'Scaffold381',
#  'Scaffold382',
#  'Scaffold383',
#  'Scaffold384',
#  'Scaffold385',
#  'Scaffold386',
#  'Scaffold387',
#  'Scaffold388',
#  'Scaffold389',
#  'Scaffold39',
#  'Scaffold390',
#  'Scaffold391',
#  'Scaffold392',
#  'Scaffold393',
#  'Scaffold394',
#  'Scaffold395',
#  'Scaffold396',
#  'Scaffold397',
#  'Scaffold398',
#  'Scaffold399',
#  'Scaffold4',
#  'Scaffold40',
#  'Scaffold400',
#  'Scaffold401',
#  'Scaffold402',
#  'Scaffold403',
#  'Scaffold404',
#  'Scaffold405',
#  'Scaffold406',
#  'Scaffold407',
#  'Scaffold408',
#  'Scaffold409',
#  'Scaffold41',
#  'Scaffold410',
#  'Scaffold411',
#  'Scaffold412',
#  'Scaffold413',
#  'Scaffold414',
#  'Scaffold415',
#  'Scaffold416',
#  'Scaffold417',
#  'Scaffold418',
#  'Scaffold419',
#  'Scaffold42',
#  'Scaffold420',
#  'Scaffold421',
#  'Scaffold422',
#  'Scaffold423',
#  'Scaffold424',
#  'Scaffold425',
#  'Scaffold426',
#  'Scaffold427',
#  'Scaffold428',
#  'Scaffold429',
#  'Scaffold43',
#  'Scaffold430',
#  'Scaffold431',
#  'Scaffold432',
#  'Scaffold433',
#  'Scaffold434',
#  'Scaffold435',
#  'Scaffold436',
#  'Scaffold437',
#  'Scaffold438',
#  'Scaffold439',
#  'Scaffold44',
#  'Scaffold440',
#  'Scaffold441',
#  'Scaffold442',
#  'Scaffold443',
#  'Scaffold444',
#  'Scaffold445',
#  'Scaffold446',
#  'Scaffold447',
#  'Scaffold448',
#  'Scaffold449',
#  'Scaffold45',
#  'Scaffold450',
#  'Scaffold451',
#  'Scaffold452',
#  'Scaffold453',
#  'Scaffold454',
#  'Scaffold455',
#  'Scaffold456',
#  'Scaffold457',
#  'Scaffold458',
#  'Scaffold459',
#  'Scaffold46',
#  'Scaffold460',
#  'Scaffold461',
#  'Scaffold462',
#  'Scaffold463',
#  'Scaffold464',
#  'Scaffold465',
#  'Scaffold466',
#  'Scaffold467',
#  'Scaffold468',
#  'Scaffold469',
#  'Scaffold47',
#  'Scaffold470',
#  'Scaffold471',
#  'Scaffold472',
#  'Scaffold473',
#  'Scaffold474',
#  'Scaffold475',
#  'Scaffold477',
#  'Scaffold478',
#  'Scaffold479',
#  'Scaffold48',
#  'Scaffold480',
#  'Scaffold481',
#  'Scaffold482',
#  'Scaffold483',
#  'Scaffold484',
#  'Scaffold485',
#  'Scaffold486',
#  'Scaffold487',
#  'Scaffold488',
#  'Scaffold489',
#  'Scaffold49',
#  'Scaffold490',
#  'Scaffold491',
#  'Scaffold492',
#  'Scaffold493',
#  'Scaffold494',
#  'Scaffold495',
#  'Scaffold496',
#  'Scaffold497',
#  'Scaffold498',
#  'Scaffold499',
#  'Scaffold5',
#  'Scaffold50',
#  'Scaffold500',
#  'Scaffold501',
#  'Scaffold502',
#  'Scaffold503',
#  'Scaffold504',
#  'Scaffold505',
#  'Scaffold506',
#  'Scaffold507',
#  'Scaffold508',
#  'Scaffold509',
#  'Scaffold51',
#  'Scaffold510',
#  'Scaffold511',
#  'Scaffold512',
#  'Scaffold513',
#  'Scaffold514',
#  'Scaffold515',
#  'Scaffold516',
#  'Scaffold517',
#  'Scaffold518',
#  'Scaffold519',
#  'Scaffold52',
#  'Scaffold521',
#  'Scaffold522',
#  'Scaffold523',
#  'Scaffold524',
#  'Scaffold525',
#  'Scaffold526',
#  'Scaffold527',
#  'Scaffold528',
#  'Scaffold529',
#  'Scaffold53',
#  'Scaffold530',
#  'Scaffold531',
#  'Scaffold532',
#  'Scaffold533',
#  'Scaffold534',
#  'Scaffold535',
#  'Scaffold537',
#  'Scaffold538',
#  'Scaffold539',
#  'Scaffold54',
#  'Scaffold540',
#  'Scaffold541',
#  'Scaffold542',
#  'Scaffold543',
#  'Scaffold544',
#  'Scaffold545',
#  'Scaffold546',
#  'Scaffold547',
#  'Scaffold548',
#  'Scaffold549',
#  'Scaffold55',
#  'Scaffold550',
#  'Scaffold551',
#  'Scaffold552',
#  'Scaffold553',
#  'Scaffold554',
#  'Scaffold555',
#  'Scaffold556',
#  'Scaffold558',
#  'Scaffold559',
#  'Scaffold56',
#  'Scaffold560',
#  'Scaffold561',
#  'Scaffold562',
#  'Scaffold563',
#  'Scaffold564',
#  'Scaffold565',
#  'Scaffold566',
#  'Scaffold567',
#  'Scaffold568',
#  'Scaffold569',
#  'Scaffold57',
#  'Scaffold570',
#  'Scaffold571',
#  'Scaffold572',
#  'Scaffold573',
#  'Scaffold574',
#  'Scaffold575',
#  'Scaffold576',
#  'Scaffold577',
#  'Scaffold578',
#  'Scaffold579',
#  'Scaffold58',
#  'Scaffold580',
#  'Scaffold581',
#  'Scaffold582',
#  'Scaffold583',
#  'Scaffold584',
#  'Scaffold585',
#  'Scaffold586',
#  'Scaffold587',
#  'Scaffold588',
#  'Scaffold589',
#  'Scaffold59',
#  'Scaffold590',
#  'Scaffold591',
#  'Scaffold592',
#  'Scaffold593',
#  'Scaffold594',
#  'Scaffold595',
#  'Scaffold596',
#  'Scaffold597',
#  'Scaffold598',
#  'Scaffold599',
#  'Scaffold6',
#  'Scaffold60',
#  'Scaffold600',
#  'Scaffold601',
#  'Scaffold602',
#  'Scaffold603',
#  'Scaffold604',
#  'Scaffold605',
#  'Scaffold606',
#  'Scaffold607',
#  'Scaffold608',
#  'Scaffold609',
#  'Scaffold61',
#  'Scaffold610',
#  'Scaffold611',
#  'Scaffold612',
#  'Scaffold613',
#  'Scaffold614',
#  'Scaffold615',
#  'Scaffold616',
#  'Scaffold617',
#  'Scaffold618',
#  'Scaffold619',
#  'Scaffold62',
#  'Scaffold620',
#  'Scaffold621',
#  'Scaffold622',
#  'Scaffold623',
#  'Scaffold624',
#  'Scaffold625',
#  'Scaffold626',
#  'Scaffold627',
#  'Scaffold628',
#  'Scaffold629',
#  'Scaffold63',
#  'Scaffold630',
#  'Scaffold631',
#  'Scaffold632',
#  'Scaffold633',
#  'Scaffold635',
#  'Scaffold636',
#  'Scaffold637',
#  'Scaffold638',
#  'Scaffold639',
#  'Scaffold64',
#  'Scaffold640',
#  'Scaffold641',
#  'Scaffold642',
#  'Scaffold643',
#  'Scaffold644',
#  'Scaffold645',
#  'Scaffold646',
#  'Scaffold647',
#  'Scaffold648',
#  'Scaffold649',
#  'Scaffold65',
#  'Scaffold650',
#  'Scaffold651',
#  'Scaffold652',
#  'Scaffold653',
#  'Scaffold654',
#  'Scaffold655',
#  'Scaffold656',
#  'Scaffold657',
#  'Scaffold658',
#  'Scaffold659',
#  'Scaffold66',
#  'Scaffold660',
#  'Scaffold661',
#  'Scaffold662',
#  'Scaffold663',
#  'Scaffold664',
#  'Scaffold665',
#  'Scaffold666',
#  'Scaffold667',
#  'Scaffold668',
#  'Scaffold669',
#  'Scaffold67',
#  'Scaffold670',
#  'Scaffold671',
#  'Scaffold672',
#  'Scaffold673',
#  'Scaffold674',
#  'Scaffold675',
#  'Scaffold676',
#  'Scaffold677',
#  'Scaffold678',
#  'Scaffold679',
#  'Scaffold68',
#  'Scaffold680',
#  'Scaffold681',
#  'Scaffold682',
#  'Scaffold683',
#  'Scaffold684',
#  'Scaffold685',
#  'Scaffold686',
#  'Scaffold687',
#  'Scaffold688',
#  'Scaffold69',
#  'Scaffold690',
#  'Scaffold691',
#  'Scaffold692',
#  'Scaffold693',
#  'Scaffold694',
#  'Scaffold695',
#  'Scaffold696',
#  'Scaffold697',
#  'Scaffold698',
#  'Scaffold699',
#  'Scaffold7',
#  'Scaffold70',
#  'Scaffold700',
#  'Scaffold701',
#  'Scaffold702',
#  'Scaffold703',
#  'Scaffold704',
#  'Scaffold705',
#  'Scaffold706',
#  'Scaffold707',
#  'Scaffold708',
#  'Scaffold709',
#  'Scaffold71',
#  'Scaffold710',
#  'Scaffold711',
#  ...]

# %% [markdown]
# # Basic Descriptive Plots:

# %% [markdown]
# ### LD as r for Scaffold0:

# %%
scaffold0 = ld[ld.CHR_A == 'Scaffold0']
scaffold0['R2'] = scaffold0.R**2

scaffold340 = ld[ld.CHR_A == 'Scaffold340']
scaffold340['R2'] = scaffold340.R**2

scaffold1091 = ld[ld.CHR_A == 'Scaffold1091']
scaffold1091['R2'] = scaffold1091.R**2

scaffold236 = ld[ld.CHR_A == 'Scaffold236']
scaffold236['R2'] = scaffold236.R**2

scaffold3000 = ld[ld.CHR_A == 'Scaffold3000']
scaffold3000['R2'] = scaffold3000.R**2
# Out:
# /home/gus/.virtualenvs/py279/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /home/gus/.virtualenvs/py279/lib/python2.7/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/gus/.virtualenvs/py279/lib/python2.7/site-packages/IPython/kernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/gus/.virtualenvs/py279/lib/python2.7/site-packages/IPython/kernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sorted(list(set(ld.CHR_A)))[:10]
# Out:
# ['JFJR01006593.1',
#  'JFJR01008464.1',
#  'JFJR01008577.1',
#  'JFJR01008756.1',
#  'JFJR01009309.1',
#  'JFJR01009825.1',
#  'JFJR01010034.1',
#  'JFJR01010145.1',
#  'JFJR01010159.1',
#  'JFJR01010160.1']

# %%
scaffold0.head()
# Out:
#        CHR_A   BP_A SNP_A     MAF_A      CHR_B   BP_B SNP_B     MAF_B  \
# 0  Scaffold0  13388     .  0.278846  Scaffold0  23408     .  0.298077
# 1  Scaffold0  13388     .  0.278846  Scaffold0  23418     .  0.298077
# 2  Scaffold0  13388     .  0.278846  Scaffold0  23421     .  0.298077
# 3  Scaffold0  13388     .  0.278846  Scaffold0  23431     .  0.288462
# 4  Scaffold0  13388     .  0.278846  Scaffold0  30544     .  0.094340
#
#           R  DP        R2
# 0  1.000000   1  1.000000
# 1  1.000000   1  1.000000
# 2  1.000000   1  1.000000
# 3  0.975946   1  0.952471
# 4  0.464238   1  0.215517

# %%
s0 = scaffold0.dropna()
sns.boxplot(s0[['R','R2','DP']], whis=np.inf, color='muted', );
sns.violinplot(s0[['R','R2','DP']], color='pastel', alpha=0.2);

# %% [markdown]
# ### LD ($r^2$) vs distance in bp for Scaffold0

# %%
bp = abs(scaffold0.BP_A - scaffold0.BP_B)

# %%
bp.head()
# Out:
# 0    10020
# 1    10030
# 2    10033
# 3    10043
# 4    17156
# dtype: int64

# %%
sns.regplot(pd.Series(bp, name="distance between SNPs"),
            pd.Series(scaffold0.R2, name=r"$r^2$"), 
            dropna=1,);

# %%
sns.jointplot(pd.Series(bp,name='distance between SNPs'),
              pd.Series(scaffold0.R**2, name="R2"),
              kind='hex',
              dropna=1);

# %% [markdown]
# #### We might need to figure out how evenly our SNPs are distributed on the Contig...

# %%
snp_locs = list(set(scaffold0.BP_A))

# %%
snp_locs[:5]
# Out:
# [2584578, 1779717, 1759238, 2584589, 1638414]

# %%
plt.hist(snp_locs, bins=150, alpha=0.3);
plt.xlabel('SNP location')
plt.ylabel('SNPs per bin')
# sns.rugplot(snp_locs);

# %%
# %matplotlib 
bw = 200000
sns.kdeplot(np.array(snp_locs), shade=1, bw=bw, label=bw);
sns.kdeplot(np.array(snp_locs), shade=0, bw=bw/2, label=bw/2);
sns.kdeplot(np.array(snp_locs), shade=0, bw=bw/4, label=bw/4);
sns.kdeplot(np.array(snp_locs), shade=0, bw=bw/6, label=bw/6);
# sns.kdeplot(np.array(snp_locs), shade=0, bw=bw/20, label=bw/20);
# sns.rugplot(snp_locs)
plt.title('Kernel density plot of SNP locations (Scaffold0)')
plt.ylabel('Density')
plt.xlabel('Location')
plt.xlim(xmin=min(snp_locs), xmax=max(snp_locs));
plt.legend(title="kernel resolution");

# %% [markdown]
# ## Lets try some other pre-existing LD data
# The following data was obatined from the [HapMap](http://hapmap.ncbi.nlm.nih.gov/downloads/index.html.en) site.
# Specifically, I am using the `ld_chr22_MEX.txt` file from 2009.

# %%
# these header values are INFERED from the text of the site but are NOT
# named in the file....
#  D', LOD , R2 
ld_22_headers = ['BP_A', 'BP_B', 'POPULATION', 'SNP_A', 'SNP_B', 'D_PRIME', 'LOD', 'R2', 'INDIVIDUALS_MAYBE'] 
ld_22 = pd.read_table(LD_22, header=None, names=ld_22_headers, sep=' +')

# %%
ld_22.head(10)
# Out:
#        BP_A      BP_B POPULATION       SNP_A       SNP_B  D_PRIME    LOD  \
# 0  14430353  14441016        MEX   rs2334386   rs9617528    1.000  0.007
# 1  14430353  14564328        MEX   rs2334386   rs7288972    1.000  0.007
# 2  14441016  14564328        MEX   rs9617528   rs7288972    0.042  0.002
# 3  14441016  14632540        MEX   rs9617528   rs9604698    1.000  0.003
# 4  14564328  14632540        MEX   rs7288972   rs9604698    1.000  0.003
# 5  14632540  14795579        MEX   rs9604698  rs12163468    1.000  0.004
# 6  14632540  14805814        MEX   rs9604698   rs7285246    1.000  0.006
# 7  14632540  14809328        MEX   rs9604698  rs12163493    1.000  0.000
# 8  14795579  14805814        MEX  rs12163468   rs7285246    1.000  0.037
# 9  14795579  14809328        MEX  rs12163468  rs12163493    1.000  0.000
#
#      R2  INDIVIDUALS_MAYBE
# 0  0.25                144
# 1  0.25                144
# 2  0.03                144
# 3  0.13                144
# 4  0.13                145
# 5  0.14                146
# 6  0.19                146
# 7  0.01                146
# 8  1.17                147
# 9  0.00                147

# %% [markdown]
# #### Rescale R2 to a normal $r^2$ range.
# For some reason HapMap scales the R2 data from 0 to 100 instead of 0 to 1

# %%
scaled_R2 = pd.Series(ld_22.R2*0.01, name="R2")
ld_22['R2_0to1'] = scaled_R2

# %% [markdown]
# ### Some comparable plotting as for our tsetse data

# %%
# get random rows from ld_22 so we plot the same data size as scaffold0
rows = np.random.choice(ld_22.index, size=scaff0_data_len, replace=False)


# do the box/violin plots
sns.boxplot(ld_22.ix[rows][['R2_0to1','D_PRIME']], whis=np.inf, color='muted', );
sns.violinplot(ld_22.ix[rows][['R2_0to1','D_PRIME']], color='pastel', alpha=0.2);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-7bd5c567be95> in <module>()
#       1 # get random rows from ld_22 so we plot the same data size as scaffold0
# ----> 2 rows = np.random.choice(ld_22.index, size=scaff0_data_len, replace=False)
#       3
#       4
#       5 # do the box/violin plots
#
# NameError: name 'scaff0_data_len' is not defined

# %%
ld_22_locs = list(set(ld_22.BP_A))

# %%
len(ld_22_locs)

# %%
bw = 2000000
sns.kdeplot(np.array(ld_22_locs), shade=1, bw=bw, label=bw);
sns.kdeplot(np.array(ld_22_locs), shade=0, bw=bw/2, label=bw/2);
sns.kdeplot(np.array(ld_22_locs), shade=0, bw=bw/4, label=bw/4);
sns.kdeplot(np.array(ld_22_locs), shade=0, bw=bw/6, label=bw/6);
# sns.kdeplot(np.array(ld_22_locs), shade=0, bw=bw/20, label=bw/20);
# sns.rugplot(ld_22_locs)
plt.title('Kernel density plot of SNP locations (Chr22 MEX)')
plt.ylabel('Density')
plt.xlabel('Location')
plt.xlim(xmin=min(ld_22_locs), xmax=max(ld_22_locs));
plt.legend(title="kernel resolution");

# %%
bp22 = abs(ld_22.BP_A - ld_22.BP_B)
bp22.head()

# %%
# abs(len(bp22[0::3])-len(bp22))

# %%
sns.regplot(pd.Series(bp22[::100], name="distance between SNPs"), 
            pd.Series(ld_22.R2[::100], name=r"$r^{2}$"), 
            lowess=0);

# %%
ld_22.R2.head()

# %%
bp22[::10].head()

# %% [markdown]
# ### Lets scale the valume of data to be the same as ours.

# %%
print "with NaN's: " + str(len(scaffold0))
scaff0_data_len = len(scaffold0.dropna())

print "no NaN's: " + str(scaff0_data_len)

# %%
ld_22['DISTANCE'] = bp22
ld_22.head()

# %%
# get random rows from ld_22
rows = np.random.choice(ld_22.index, size=scaff0_data_len, replace=False)

sns.jointplot(ld_22.ix[rows].DISTANCE, 
              ld_22.ix[rows].R2/100., 
              kind="hex",);
# plt.xlabel('distance in bp between SNPs');
# plt.ylabel(r'LD ($r^2$)');

# %%
len(rows)
