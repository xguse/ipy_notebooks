# %%
import pandas as pd

# %%
dump = pd.read_excel('/home/gus/MEGAsync/zim/main/Yale/Projects/G_fuscipes/Gff_database/dump_database_for_mary_b/consolidated_old_and_2014_Gff_db_dump_FROM_OPENREFINE.xls')

# %%
dump.head()
# Out:
#         pre_openrefine_file comment                 date   dead fly_number  \
# 0  2014_excel_db.xls#Sheet1  !blank  2014-07-22 00:00:00  False          1
# 1  2014_excel_db.xls#Sheet1  !blank  2014-07-22 00:00:00  False          2
# 2  2014_excel_db.xls#Sheet1  !blank  2014-07-22 00:00:00  False          3
# 3  2014_excel_db.xls#Sheet1  !blank  2014-07-22 00:00:00  False          4
# 4  2014_excel_db.xls#Sheet1  !blank  2014-07-22 00:00:00  False          5
#
#   hunger_stage kept_in sex species teneral   ...    mrsA_PCR sample volume  \
# 0            2    EtOH   F     Gff   False   ...                    !blank
# 1            3    EtOH   F     Gff   False   ...                    !blank
# 2            3    EtOH   M     Gff   False   ...                    !blank
# 3            3    EtOH   M     Gff   False   ...                    !blank
# 4            3    EtOH   M     Gff   False   ...                    !blank
#
#   mrsA_Seq population public_notes    size source_file  \
# ...
