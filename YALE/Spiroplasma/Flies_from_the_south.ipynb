# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(llcrnrlon=30.182,llcrnrlat=-1.317,urcrnrlon=37.283,urcrnrlat=2.849, resolution = 'h', epsg=4326)

map.drawmapboundary(fill_color='aqua')
#Fill the continents with the land color
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcountries(linewidth=0.25)
map.drawcoastlines()
 
plt.show()

# %%
import pandas as pd

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import random as rand

# %%
run /home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/scripts/gff_pandas_database.py
# Out:
# Main dataframe is dfp: and is only Gff.
# /home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/scripts/gff_pandas_database.py:330: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#   if 'NAN' in exc.message.upper():

# %%
run /home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/scripts/2015-03-24_looking_for_infections_in_old_files.py
# Out:
# /home/gus/anaconda2/envs/stack2/lib/python2.7/site-packages/pandas/core/indexing.py:490: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# /home/gus/anaconda2/envs/stack2/lib/python2.7/site-packages/pandas/core/indexing.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 'provided_dataframes' contains refs to useful dataframes.

# %%
# Load Chaz MSAT individuals
table_msat = pd.read_csv('/home/gus/Documents/YalePostDoc/project_stuff/g_f_fucipes_uganda/microsat/GffMsats_1480individuals_ID_list.csv')
table_msat.head(10)
# Out:
#   Fly Number
# 0   AM11e001
# 1   AM11e002
# 2   AM11e003
# 3   AM11e004
# 4   AM11e005
# 5   AM11e006
# 6   AM11e008
# 7   AM11e009
# 8   AM11e010
# 9   AM11e013

# %%
provided_dataframes.keys()
# Out:
# ['df_samples',
#  'traps_gps_uganda',
#  'villages_gps_uganda',
#  'wolbachia_data_orig',
#  'uganda',
#  'df_tryps',
#  'table_latlon']

# %% [markdown]
# # From looking at papers southern sites include:
#
# - BK
# - BKD
# - BN
# - BU
# - BV
# - BY
# - BZ
# - DB
# - EB
# - IGG
# - JN
# - KF
# - KG
# - KIS
# - KL
# - KO
# - LI
# - MA
# - MGG
# - MK
# - NA
# - NAM
# - ND
# - NS
# - OK
# - OS
# - PT
# - SA
# - TB

# %%
df_samples.iloc[rand.sample(range(len(df_samples)), 10)]
# Out:
#     aliguot_n aliquot_n banked_sample_id      collection_date collection_id  \
# 473       NaN       NaN          OK09091  2009-04-01 00:00:00          OKXX
# 18        NaN                     NA1.19  2008-12-03 00:00:00     NAXX-2008
# 79        NaN       NaN           JN1.87               4/x/08     JN01-2008
# 24        NaN       NaN           BU10.5  2008-03-13 00:00:00     BU10-2008
# 51        NaN                  Apac-L114  2007-08-14 00:00:00     APXX-2007
# 60        NaN       NaN          BV08022               4/x/08        Bvbulk
# 52        NaN       NaN          BU10.33                39520     BU10-2008
# 234       NaN       NaN            SI5.2  2008-03-13 00:00:00     SI05-2008
# 215       NaN       NaN          KL09085               4/x/09     KLXX-2009
# 9         NaN       NaN          OY09023  2009-07-17 00:00:00     OY01-2009
#
#     collection_id.1 curation_date curator food_state id internal_notes  \
# 473             NaN
# 18              NaN
# 79              NaN
# 24              NaN
# 51              NaN
# 60              NaN
# 52              NaN
# 234             NaN
# 215             NaN
# 9               NaN
#
#     internal_notes.1 life_stage population  public_notes  sex size  \
# 473              NaN                    OK   Storage=N/A    F    1
# 18               NaN                    NA                  M    1
# 79               NaN                    JN           N/A    M    1
# 24               NaN                    BU  storage=S002    F    1
# 51               NaN                                        M    1
# 60               NaN                    BV   storage N/A    M    1
# 52               NaN                    BU  storage=S002    M    1
# 234              NaN                    SI  storage=S002    F    1
# 215              NaN                    KL   storage N/A    M    1
# 9                NaN                    OY   Storage=N/A  N/A    1
#
#       species_id species_id.1 species_identification  \
# 473  G. fuscipes          NaN                    NaN
# 18   G. fuscipes          NaN                    NaN
# 79   G. fuscipes          NaN                    NaN
# 24   G. fuscipes          NaN                    NaN
# 51   G. fuscipes          NaN                    NaN
# 60   G. fuscipes          NaN                    NaN
# 52   G. fuscipes          NaN                    NaN
# 234  G. fuscipes          NaN                    NaN
# 215  G. fuscipes          NaN                    NaN
# 9    G. fuscipes          NaN                    NaN
#
#     species_identification_method_id specimen_id stoage storage  \
# 473                                          NaN    NaN     NaN
# 18                                                  NaN
# 79                                           NaN    NaN     NaN
# 24                                           NaN    NaN     NaN
# 51                                                  NaN
# 60                                           NaN    NaN     NaN
# 52                                           NaN    NaN     NaN
# 234                                          NaN    NaN     NaN
# 215                                          NaN    NaN     NaN
# 9                                            NaN    NaN     NaN
#
#          submission_date                  submitter tissue tube_num
# 473  2010-06-15 00:00:00  J Beadell;B Symula;U Alam    NaN
# 18            2010-06-01  J Beadell;B Symula;U Alam              19
# 79   2010-06-05 00:00:00  J Beadell;B Symula;U Alam    NaN       87
# 24            2010-06-01  J Beadell;B Symula;U Alam    NaN        5
# 51                                                             L114
# 60   2010-06-06 00:00:00  J Beadell;B Symula;U Alam    NaN       22
# 52            2010-06-01  J Beadell;B Symula;U Alam    NaN       33
# 234           2010-06-01  J Beadell;B Symula;U Alam    NaN        2
# 215  2010-06-17 00:00:00  J Beadell;B Symula;U Alam    NaN       85
# 9    2010-06-17 00:00:00  J Beadell;B Symula;U Alam    NaN

# %%
def fuzzy_filter(item, targets):
    """Returns boolean if filter is successfull on ``item``.

    Args:
        item (str): string in dataframe column to be filtered
        targets (list): list of location codes we want from the database.

    Returns:
        boolean
    """

    hit = process.extractOne(item, targets)
    return hit[-1] >= 80

def mask_by_fuzzy(targets, db_col):
    """Creates extraction mask to pull out targets from db based on fuzzy matching.
    
    Args:
        targets (list): list of location codes we want from the database.
        db_col (Series): dataframe column representing the vaules to be filtered.
    

    Returns:
        pandas mask
    """
    
    mask = db_col.apply(fuzzy_filter, targets=targets)
    
    return mask

# %%
south_locs = ["BK","BKD","BN","BU","BV","BY","BZ","DB","EB","IGG","JN","KF","KG","KIS","KL","KO","LI","MA","MGG","MK","NA","NAM","ND","NS","OK","OS","PT","SA","TB"]

# %%
hit = process.extractOne(u'NAM',table_msat['Fly Number'])
print hit
hit[-1] >= 80
# Out:
# ('NAM11_156', 90)
# True

# %%
hit2 = process.extractOne('bv', table_msat['Fly Number'])
print hit2[-1] >= 80
print hit2
# Out:
# False
# ('BK09e0100', 45)

# %%
south_mask = mask_by_fuzzy(targets=south_locs, db_col=df_samples.banked_sample_id)
south_mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: banked_sample_id, dtype: bool

# %%
smask = uganda.id.apply(lambda x: True if x in south_locs else False)

# %%
south_villages = uganda.query("latitude <= 1.481837")
south_villages
# Out:
#        id                 name gaz_id  latitude  longitude country   district  \
# 2      BB            Bulanga B         1.068104  33.777342  Uganda     Budaka
# 3    BB20    Bulanga B Trap 20         1.072800  33.779530  Uganda     Budaka
# 4    BB21    Bulanga B Trap 21         1.072500  33.779380  Uganda     Budaka
# 5    BB22    Bulanga B Trap 22         1.072130  33.778800  Uganda     Budaka
# 6    BB23    Bulanga B Trap 23         1.071740  33.778950  Uganda     Budaka
# 7    BB24    Bulanga B Trap 24         1.071960  33.779000  Uganda     Budaka
# 8    BB25    Bulanga B Trap 25         1.065930  33.778490  Uganda     Budaka
# 9    BB26    Bulanga B Trap 26         1.065930  33.776830  Uganda     Budaka
# 10   BB27    Bulanga B Trap 27         1.062750  33.774090  Uganda     Budaka
# 11   BB28    Bulanga B Trap 28         1.062980  33.774180  Uganda     Budaka
# 12   BB29    Bulanga B Trap 29         1.062320  33.774170  Uganda     Budaka
# 13     BD              Budonga         0.260933  33.929463  Uganda      Busia
# 14   BD14      Budonga Trap 14         0.260770  33.929420  Uganda      Busia
# 15   BD15      Budonga Trap 15         0.260860  33.929550  Uganda      Busia
# 16   BD16      Budonga Trap 16         0.261170  33.929420  Uganda      Busia
# 31     BK              Nabiswa         1.006550  33.857650  Uganda    Pallisa
# 32     BK              Nabiswa         1.012690  33.861300  Uganda    Pallisa
# 33     BK               Kadama         1.010407  33.861218  Uganda    Pallisa
# 34   BK01   Nabiswa location 1         1.006550  33.857650  Uganda    Pallisa
# 35   BK01       Nabiswa Trap 1         1.012690  33.861300  Uganda    Pallisa
# 36   BK01        Kadama Trap 1         1.012480  33.861290  Uganda    Pallisa
# 37   BK02   Nabiswa location 2         1.006810  33.857370  Uganda    Pallisa
# 38   BK02       Nabiswa Trap 2         1.012260  33.861540  Uganda    Pallisa
# 39   BK02        Kadama Trap 2         1.012720  33.861500  Uganda    Pallisa
# 40   BK03       Nabiswa Trap 3         1.012310  33.861520  Uganda    Pallisa
# 41   BK03        Kadama Trap 3         1.012290  33.861470  Uganda    Pallisa
# 42   BK04       Nabiswa Trap 4         1.012480  33.861260  Uganda    Pallisa
# 43   BK04        Kadama Trap 4         1.012270  33.861260  Uganda    Pallisa
# 33            BK
# 34            BK
# 35            BK
# 36            BK
# 37            BK
# 38            BK
# 39            BK
# 40            BK
# 41            BK
# 42            BK
# 43            BK
# 44            BK
# 45            BK
# 46            BK
# 47            BK
# 48            BK
# 49            BN
# 50            BN
# 51            BN
# 52            BN
# 53            BN
# 54            BN
# 55            BN
# 56            BN
# 57            BN
# 58            BN
# 59            BN
# 60            BN
# 61            BN
# 62            BN
# 63            BN
# 64            BN
# 66            BU
# ..           ...
# 143           KY
# 144           KY
# 145           KY
# 146           KY
# 147           KY
# 148           KY
# 149           KY
# 150           KY
# 151           KY
# 165           MK
# 166           MK
# 167           MK
# 168           MK
# 169           MK
# 170           MK
# 171           MK
# 172           MK
# 173           MK
# 174           MK
# 175           MK
# 176           MK
# 177           MK
# 178           MK
# 179           MK
# 180           MK
# 181           MK
# 182           MP
# 228           NA
# 229           NA
# 230           NA
# 231           NA
# 232           NA
# 233           NA
# 234           NB
# 239           OK
# 240           OK
# 241           OK
# 242           OK
# 243           OK
# 244           OK
# 245           OK
# 246           OK
# 247           OK
# 248           OK
# 249           OK
# 261           SI
# 262           SI
# 263           SI
# 264           SI
# 269           TR
#
# [157 rows x 8 columns]

# %%
south_villages.query("village_code == 'BV'")
# Out:
#       id                   name gaz_id  latitude  longitude country district  \
# 73    BV          Buvuma Island          0.47416   33.38236  Uganda   Mukono
# 74  BV01   Buvuma Island Trap 1          1.34698   33.89325  Uganda   Mukono
# 75  BV11  Buvuma Island Trap 11          0.25643   33.20635  Uganda   Mukono
# 76  BV12  Buvuma Island Trap 12          0.30733   33.29325  Uganda   Mukono
# 77  BV13  Buvuma Island Trap 13          0.31060   33.29360  Uganda   Mukono
# 78  BV14  Buvuma Island Trap 14          0.31209   33.30392  Uganda   Mukono
# 79  BV15  Buvuma Island Trap 15          0.31153   33.30379  Uganda   Mukono
#
#    village_code
# 73           BV
# 74           BV
# 75           BV
# 76           BV
# 77           BV
# 78           BV
# 79           BV

# %%
south_villages_gps = south_villages[['latitude','longitude','village_code']].groupby('village_code').mean()
south_villages_gps
# Out:
#               latitude  longitude
# village_code
# BB            1.068104  33.777342
# BD            0.260933  33.929463
# BK            1.009727  33.860004
# BN            0.940966  33.973218
# BU            0.248867  33.970927
# BV            0.474160  33.382360
# JN            1.332193  32.738184
# KA            1.046104  33.771181
# KB            0.977190  30.546500
# KK            0.364650  30.279960
# KL            0.166700  32.766700
# KP            1.007965  33.855469
# KT            0.082080  32.485050
# KW            1.017428  33.874041
# KY            1.449669  33.657465
# MK            1.358237  33.873001
# MP            0.303520  30.532090
# NA            0.763196  33.650187
# NB            0.863130  33.729290
# OK            0.519560  34.118511
# SI            0.260303  34.017557
# TR            0.612080  34.185535

# %%
south_villages_gps.to_clipboard()

# %%
mask_ = mask_by_fuzzy(targets=south_villages.village_code.unique(), db_col=table_msat["Fly Number"])
mask_.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Fly Number, dtype: bool

# %%
genotyped_from_south = table_msat[mask_]
genotyped_from_south
# Out:
#           Fly Number
# 30         BK09e0100
# 31         BK09e0104
# 32         BK09e0107
# 33         BK09e0111
# 34         BK09e0113
# 35         BK09e0114
# 36         BK09e0116
# 37         BK09e0119
# 38         BK09e0121
# 39         BK09e0131
# 40         BK09e0133
# 41         BK09e0135
# 42         BK09e0136
# 43         BK09e0141
# 44         BK09e0152
# 45         BK09e0156
# 46         BK09e0161
# 47         BK09e0162
# 48         BK09e0173
# 49         BK09e0175
# 50         BK09e0176
# 51         BK09e0179
# 52         BK09e0181
# 53         BK09e0186
# 54         BK09e0188
# 55         BK09e0190
# 56         BK09e0192
# 57         BK09e0195
# 58         BK09e0196
# 59         BK09e0199
# 60         BK09e0202
# 61         BK09e0203
# 62         BK09e0204
# 63         BK09e0210
# 64         BK09e0218
# 65         BK09e0221
# 66         BK09e0225
# 67         BK09e0228
# 68         BK09e0229
# 69         BK09e0232
# 70           BK09001
# 71           BK09003
# 72           BK09004
# 73           BK09005
# 74           BK09008
# 75           BK09010
# 76           BK09011
# 77           BK09012
# 78           BK09013
# 79           BK09014
# ...              ...
# 1011        OKb09059
# 1012        OKb09061
# 1013        OKb09062
# 1014        OKb09063
# 1015        OKb09064
# 1016        OKb09065
# 1017        OKb09066
# 1018        OKb09067
# 1019          OK1001
# 1020          OK1002
# 1021          OK1003
# 1022          OK1005
# 1023           OK207
# 1024          OK4027
# 1025          OK4028
# 1026          OK4029
# 1027          OK4030
# 1028          OK4031
# 1029          OK4032
# 1030          OK4033
# 1031          OK4034
# 1032          OK4037
# 1033          OK4038
# 1034          OK4039
# 1035          OK4040
# 1036          OK4041
# 1037          OK4042
# 1038          OK4043
# 1039          OK4044
# 1040          OK4045
# 1041          OK4053
# 1042          OK4054
# 1043          OK4055
# 1044          OK4056
# 1045          OK4057
# 1046          OK4058
# 1047           OK701
# 1048           OK702
# 1049           OK707
# 1050           OK801
# 1051           OK803
# 1052           OK804
# 1053           OK805
# 1054           OK806
# 1055           OK901
# 1056           OK902
# 1057           OK903
# 1408         KB4_G35
# 1409         KL5_G79
# 1479  Gff_ETH-Kl1022
#
# [699 rows x 1 columns]

# %%
len(genotyped_from_south)
# Out:
# 699

# %%
genotyped_from_south.to_clipboard()

# %% [markdown]
# # Get Robert a list of likely southern genotyped flies

# %%
# df_samples_typed = pd.merge(left=table_msat, right=df_samples, 
#                              how='inner', 
#                              on=None, left_on="Fly Number", right_on="banked_sample_id", 
#                              left_index=False, right_index=False, 
#                              sort=False, suffixes=('_x', '_y'), copy=True)


# # df_samples_typed  # these ONLY contain BK09 tubes

# %%
# df_samples_typed = pd.merge(left=table_msat, right=df_samples, 
#                              how='inner', 
#                              on=None, left_on="Fly Number", right_on="banked_sample_id", 
#                              left_index=False, right_index=False, 
#                              sort=False, suffixes=('_x', '_y'), copy=True)
