# %% [markdown]
# # Purpose:
#
# 2015-02-12 (Thursday)
#
# use pandas to get Gisella something more like what she said she wanted in terms of summary tables for the _G. pallidipes_ summary table information:
#
# - data types:
#     - location
#     - symbols when present (_I assume this mean location symbol?_)
#     - number of individuals
#     - date range
#     - is tissue?
#     - is extraction?
#     - analysis status
#
# __Notes:__
#
# - group by location
# - filter on Kenya locations (not sure which locations are kenya if not explicit)

# %% [markdown]
# # Implementation:

# %% [markdown]
# ## Imports:

# %%
# imports
import pandas as pd
import numpy as np

import qgrid as qg

# %%
qg.nbinstall()

# %%
qshow = qg.show_grid

# %% [markdown]
# ## File paths:

# %%
# define paths to files

xl_path = '/home/gus/Documents/YalePostDoc/project_stuff/G_pallidipes_kenya/Collection_data_updated_Feb_9_2015.xlsx'

# %% [markdown]
# ## Load data

# %%
xl = pd.ExcelFile(xl_path)

# %%
xl.sheet_names
# Out:
# [u'cold room',
#  u'idaho boxes',
#  u'Idaho strip tube boxes',
#  u'gisella freezer',
#  u'-80 freezer',
#  u'dissection_sheet_template']

# %%
sample_cat = xl.parse(sheetname=u'dissection_sheet_template', 
         header=0, 
         skiprows=None, skip_footer=0, 
         index_col=None, parse_cols=None, 
         parse_dates=False, date_parser=None, 
         na_values=['NA'], 
         thousands=None, chunksize=None, 
         convert_float=False, 
         has_index_names=False, converters=None)

# %%
qshow(sample_cat,remote_js=True)
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/6988858671b6f80c7d1987e07ebff3dc810d20ce/qgrid/qgridjs//lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/6988858671b6f80c7d1987e07ebff3dc810d20ce/qgrid/qgridjs//lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='https://cdn.rawgit.com/quantopian/qgrid/6988858671b6f80c7d1987e07ebff3dc810d20ce/qgrid/qgridjs//qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='6d9f3371-4c11-4312-9dac-a4180a49ba19' class='q-grid'></div>
# </div>

# %% [markdown]
# ## Manipulate table to facilitate pivot operations

# %%
# add a number column to represent that each row is ONE sample
sample_cat['Count'] = 1

# %% [markdown]
# ### Convert Gpd to Gp

# %%
try:
    gpd_mask.head()
except NameError:
    gpd_mask = sample_cat.Species == 'Gpd'

# %%
sample_cat.loc[gpd_mask,'Species'] = 'Gp'

# %%
sample_cat[gpd_mask].head(1)
# Out:
#                           Lab_Source               Village Trap_No  Date  \
# 2135  EPH Idaho Samples (Tube Boxes)  Galana (?) D1, Kenya       0  Unk.
#
#      Species Sex  Teneral  Dead Fly_Number  Hunger_stage  ...   midgut  \
# 2135      Gp   M      NaN   NaN        018           NaN  ...      NaN
#
#       sal_gland  Kept_in                                            Comment  \
# 2135        NaN     Unk.  CTAB, color coded aliquots, poorly labelled an...
#
#      Tube_or_box Tissue Derivative Method_of_prep Box_number_id Count
# 2135         box    NaN       gDNA            NaN            50     1
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Convert Date: Unk, Unk., etc to single value (Unk)

# %%
def date_unk_func(x):
    try:
        if x.upper().startswith('UNK'):
            return 'UNK'
        else:
            return x
    except AttributeError:
        return x
    
def standardize_date_unk(df):
    new = df.Date.apply(date_unk_func)
    df.Date = new

# %%
standardize_date_unk(sample_cat)

# %% [markdown]
# ### Add tissue_or_derivative column

# %%
sample_cat['tissue_or_extraction'] = 'none'

# %%
# generate masks of which rows match tissue or derivative
try:
    is_tissue_mask.head()
except NameError:
    is_tissue_mask =  sample_cat.Tissue.apply(lambda x: isinstance(x, (unicode, str)))
    
try:
    is_derivative_mask.head()
except NameError:
    is_derivative_mask =  sample_cat.Derivative.apply(lambda x: isinstance(x, (unicode, str)))

# %%
sample_cat.loc[is_tissue_mask, 'tissue_or_extraction'] = 'tissue'
sample_cat.loc[is_derivative_mask, 'tissue_or_extraction'] = 'extraction'

# %% [markdown]
# ## Begin Pivots

# %%
ptab = pd.pivot_table(sample_cat,index=['Village', 'Lab_Source','Date', 'Species'],
                      values=['Count'],
                      columns=['tissue_or_extraction'],
                      fill_value=0,
                      aggfunc=[np.sum])

# %%
ptab.query('Species == ["Gp"]')
# Out:
#                                                                                                                   sum  \
#                                                                                                                 Count
# tissue_or_extraction                                                                                       extraction
# Village                                   Lab_Source                           Date                Species
# "Africa" P.M.S.                           EPH Idaho Samples (Tube Boxes)       2002-11/12          Gp              46
# Arba Minch, Ethiopia                      EPH -80                              1997-01-11 00:00:00 Gp              18
#                                           EPH Idaho Samples (Strip Tube Boxes) 1997-01             Gp              24
#                                                                                UNK                 Gp              48
#                                           EPH Idaho Samples (Tube Boxes)       UNK                 Gp              32
# Arba Minch, Ethiopia, P3                  EPH Idaho Samples (Tube Boxes)       UNK                 Gp              24
# Arba Minch, Ethiopia, P6                  EPH Idaho Samples (Tube Boxes)       UNK                 Gp              24
# Block A (Ruma?), Kenya                    EPH Idaho Samples (Strip Tube Boxes) 2003-11-02          Gp             400
# Busia, Kenya                              EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              48
# Campsite                                  EPH Idaho Samples (Strip Tube Boxes) 2003-12-12          Gp              34
# Changara, Mozambique                      EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              54
# Dakabuko, Galana, Kenya                   EPH Idaho Samples (Strip Tube Boxes) 2000-02-25          Gp              96
#                                                                                UNK                 Gp              24
# Deme River, Ethiopia                      EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              24
# Galana (?)  K5, Kenya                     EPH Idaho Samples (Tube Boxes)       UNK                 Gp               9
# Galana (?) D1, Kenya                      EPH Idaho Samples (Tube Boxes)       UNK                 Gp               8
# Galana (?) K2, Kenya                      EPH Idaho Samples (Tube Boxes)       UNK                 Gp               7
# Galana, Kenya                             Gisella Freezer Samples              2000-02             Gp              24
# Kabukanga, Uganda                         Gisella Freezer Samples              2008-04             Gp              40
#                                                                                UNK                 Gp               4
# Kabunkanga, Kibale District, Kenya        Cold Room Samples (156b)             2010-09-23          Gp               0
#                                                                                2010-09-24          Gp               0
#                                                                                2010-09-25          Gp               0
# Kakumbi, Zambia                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              24
# Kalema, Kenya                             EPH Idaho Samples (Strip Tube Boxes) 2000                Gp              18
# Kapesur, Kenya                            Cold Room Samples (156b)             2009-03             Gp               0
#                                                                                2009-07             Gp               0
#                                           Gisella Freezer Samples              2009-03             Gp               6
#                                                                                2009-03-15          Gp              96
# Kathekani, Kenya                          EPH Idaho Samples (Strip Tube Boxes) 2000-12-22          Gp              56
# ...                                                                                                               ...
# Ruma Nat'l Park, Block A, Site 17, Kenya  EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp              48
# Ruma Nat'l Park, Block A, Site 6, Kenya   EPH Idaho Samples (Strip Tube Boxes) 2003-05-27          Gp              40
#                                           EPH Idaho Samples (Tube Boxes)       2003-06-25          Gp              48
# Ruma Nat'l Park, Block A, Site AN, Kenya  EPH -80                              2003-05-28 00:00:00 Gp              48
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-05-29          Gp              48
# Ruma Nat'l Park, Block B, Site BN1, Kenya EPH -80                              2003-04-26 00:00:00 Gp              48
# Ruma Nat'l Park, Block B, Site BN2, Kenya EPH Idaho Samples (Tube Boxes)       2003-04-26          Gp              48
# Ruma Nat'l Park, Block B, Site BN3, Kenya EPH -80                              2003-04-26 00:00:00 Gp              48
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-04-20          Gp              48
#                                                                                2003-04-26          Gp              48
# Ruma Nat'l Park, Block B, Site BN4, Kenya EPH -80                              2003-04-26 00:00:00 Gp              48
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp              96
# Ruma Nat'l Park, Block B, Site BN5, Kenya EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp              48
# Ruma Nat'l Park, Block C, Site C2, Kenya  EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp              48
# Ruma Nat'l Park, Block C, Site CN1, Kenya EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp              48
# Sampu Camp, Nguruman, Kenya               EPH -80                              2002-02-27 00:00:00 Gp              26
# Serengeti, Tanzania                       EPH Idaho Samples (Strip Tube Boxes) 2003-06-27          Gp              33
#                                                                                UNK                 Gp              48
# Shimba Hills, Kenya                       EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              48
#                                           EPH Idaho Samples (Tube Boxes)       UNK                 Gp              48
# Shompole, Kenya                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              48
# Tanga, Tanzania                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              48
# Tarangire South (Chubi area), Tanzania    EPH Idaho Samples (Strip Tube Boxes) 2004-04-27          Gp             202
# Tarangire, Sangaiwe, Tanzania             EPH Idaho Samples (Strip Tube Boxes) 2004-04-29          Gp              92
# Tsavo West, Kenya                         EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp              48
# Uganda                                    EPH -80                              1998-03-13 00:00:00 Gp              24
#                                                                                1997-12             Gp              41
# Zambia                                    EPH -80                              1998-01-29 00:00:00 Gp              24
#                                                                                1998-03-13 00:00:00 Gp              24
# cAG (?)                                   EPH Idaho Samples (Tube Boxes)       UNK                 Gp               5
#
#
#
# tissue_or_extraction                                                                                       tissue
# Village                                   Lab_Source                           Date                Species
# "Africa" P.M.S.                           EPH Idaho Samples (Tube Boxes)       2002-11/12          Gp          54
# Arba Minch, Ethiopia                      EPH -80                              1997-01-11 00:00:00 Gp          32
#                                           EPH Idaho Samples (Strip Tube Boxes) 1997-01             Gp           0
#                                                                                UNK                 Gp           0
#                                           EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Arba Minch, Ethiopia, P3                  EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Arba Minch, Ethiopia, P6                  EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Block A (Ruma?), Kenya                    EPH Idaho Samples (Strip Tube Boxes) 2003-11-02          Gp           0
# Busia, Kenya                              EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Campsite                                  EPH Idaho Samples (Strip Tube Boxes) 2003-12-12          Gp           0
# Changara, Mozambique                      EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Dakabuko, Galana, Kenya                   EPH Idaho Samples (Strip Tube Boxes) 2000-02-25          Gp           0
#                                                                                UNK                 Gp           0
# Deme River, Ethiopia                      EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Galana (?)  K5, Kenya                     EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Galana (?) D1, Kenya                      EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Galana (?) K2, Kenya                      EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Galana, Kenya                             Gisella Freezer Samples              2000-02             Gp           0
# Kabukanga, Uganda                         Gisella Freezer Samples              2008-04             Gp           0
#                                                                                UNK                 Gp           0
# Kabunkanga, Kibale District, Kenya        Cold Room Samples (156b)             2010-09-23          Gp           4
#                                                                                2010-09-24          Gp           5
#                                                                                2010-09-25          Gp           5
# Kakumbi, Zambia                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Kalema, Kenya                             EPH Idaho Samples (Strip Tube Boxes) 2000                Gp           0
# Kapesur, Kenya                            Cold Room Samples (156b)             2009-03             Gp          23
#                                                                                2009-07             Gp          18
#                                           Gisella Freezer Samples              2009-03             Gp           0
#                                                                                2009-03-15          Gp           0
# Kathekani, Kenya                          EPH Idaho Samples (Strip Tube Boxes) 2000-12-22          Gp           0
# ...                                                                                                           ...
# Ruma Nat'l Park, Block A, Site 17, Kenya  EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp           0
# Ruma Nat'l Park, Block A, Site 6, Kenya   EPH Idaho Samples (Strip Tube Boxes) 2003-05-27          Gp           0
#                                           EPH Idaho Samples (Tube Boxes)       2003-06-25          Gp           0
# Ruma Nat'l Park, Block A, Site AN, Kenya  EPH -80                              2003-05-28 00:00:00 Gp           0
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-05-29          Gp           0
# Ruma Nat'l Park, Block B, Site BN1, Kenya EPH -80                              2003-04-26 00:00:00 Gp           0
# Ruma Nat'l Park, Block B, Site BN2, Kenya EPH Idaho Samples (Tube Boxes)       2003-04-26          Gp           0
# Ruma Nat'l Park, Block B, Site BN3, Kenya EPH -80                              2003-04-26 00:00:00 Gp           0
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-04-20          Gp           0
#                                                                                2003-04-26          Gp           0
# Ruma Nat'l Park, Block B, Site BN4, Kenya EPH -80                              2003-04-26 00:00:00 Gp           0
#                                           EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp           0
# Ruma Nat'l Park, Block B, Site BN5, Kenya EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp           0
# Ruma Nat'l Park, Block C, Site C2, Kenya  EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp           0
# Ruma Nat'l Park, Block C, Site CN1, Kenya EPH Idaho Samples (Strip Tube Boxes) 2003-04-26          Gp           0
# Sampu Camp, Nguruman, Kenya               EPH -80                              2002-02-27 00:00:00 Gp           0
# Serengeti, Tanzania                       EPH Idaho Samples (Strip Tube Boxes) 2003-06-27          Gp           0
#                                                                                UNK                 Gp           0
# Shimba Hills, Kenya                       EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
#                                           EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
# Shompole, Kenya                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Tanga, Tanzania                           EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Tarangire South (Chubi area), Tanzania    EPH Idaho Samples (Strip Tube Boxes) 2004-04-27          Gp           0
# Tarangire, Sangaiwe, Tanzania             EPH Idaho Samples (Strip Tube Boxes) 2004-04-29          Gp           0
# Tsavo West, Kenya                         EPH Idaho Samples (Strip Tube Boxes) UNK                 Gp           0
# Uganda                                    EPH -80                              1998-03-13 00:00:00 Gp           0
#                                                                                1997-12             Gp           0
# Zambia                                    EPH -80                              1998-01-29 00:00:00 Gp           0
#                                                                                1998-03-13 00:00:00 Gp           0
# cAG (?)                                   EPH Idaho Samples (Tube Boxes)       UNK                 Gp           0
#
# [147 rows x 2 columns]
