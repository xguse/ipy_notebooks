# %% [markdown]
# # Purpose:
#
# 2015-07-29 (Wed)
#
# use pandas to query Krafsur collection

# %% [markdown]
# # Implementation:

# %% [markdown]
# ## Imports:

# %%
# imports

import pandas as pd
pd.set_option('display.max_columns', 60)

import numpy as np

# %% [markdown]
# ## File paths:

# %%
# define paths to files

xl_path = "/home/gus/Documents/YalePostDoc/project_stuff/G_pallidipes_kenya/Krafsur_Collection_data_updated_Feb_9_2015.xlsx"

# %% [markdown]
# ## Load data

# %%
table = pd.read_excel(xl_path,sheetname="dissection_sheet_template")
table = table.dropna(axis=1, how="all")

# %%
table.head()
# Out:
#   Lab_Source               Village Trap_No                 Date Species Sex  \
# 0    EPH -80  Arba Minch, Ethiopia       0  1997-01-11 00:00:00      Gp   F
# 1    EPH -80  Arba Minch, Ethiopia       0  1997-01-11 00:00:00      Gp   F
# 2    EPH -80  Arba Minch, Ethiopia       0  1997-01-11 00:00:00      Gp   F
# 3    EPH -80  Arba Minch, Ethiopia       0  1997-01-11 00:00:00      Gp   F
# 4    EPH -80  Arba Minch, Ethiopia       0  1997-01-11 00:00:00      Gp   F
#
#   Fly_Number  sal_gland Kept_in                            Comment  \
# 0          1          0    Unk.  Appears to be small volume of DNA
# 1          2          0    Unk.  Appears to be small volume of DNA
# 2          3          0    Unk.  Appears to be small volume of DNA
# 3          4          0    Unk.  Appears to be small volume of DNA
# 4          5          0    Unk.  Appears to be small volume of DNA
#
#   Tube_or_box Tissue Derivative Method_of_prep  Box_number_id
# 0         box    NaN       gDNA            NaN              1
# 1         box    NaN       gDNA            NaN              1
# 2         box    NaN       gDNA            NaN              1
# 3         box    NaN       gDNA            NaN              1
# 4         box    NaN       gDNA            NaN              1

# %% [markdown]
# # Get Michael more samples (hopefully flies)

# %%
table_villages =  set(table.Village.unique())
table_villages
# Out:
# {u'"Africa" P.M.S.',
#  u'A2 (?)',
#  u'Angwa, Shompole, Kenya',
#  u'Arba Minch, Ethiopia',
#  u'Arba Minch, Ethiopia, P3',
#  u'Arba Minch, Ethiopia, P6',
#  u'Bansang, Gambia',
#  u'Block A (Ruma?), Kenya',
#  u'Botswana',
#  u'Botswana, Kondo',
#  u'Botswana, Unit 1',
#  u'Botswana, Unit 2',
#  u'Box N, "Rio" (check comments)',
#  u'Busia, Kenya',
#  u'Campsite',
#  u'Changara , Mozambique',
#  u'Changara, Mozambique',
#  u'Dakabuko, Galana, Kenya',
#  u'Deme River, Ethiopia',
#  u'Diak Sao, Senegal',
#  u'Galana (?)  K5, Kenya',
#  u'Galana (?) D1, Kenya',
#  u'Galana (?) K2, Kenya',
#  u'Galana, Kenya',
#  u'ILRI',
#  u'Kabukanga, Uganda',
#  u'Kabunkanga, Kibale District, Kenya',
#  u'Kakumbi, Zambia',
#  u'Kalema, Kenya',
#  u'Kapesur, Kenya',
#  u'Kathekani, Kenya',
#  u'Katima, Namibia',
#  u'Ketri Insectary, Kenya',
#  u'Kibwezi, Tanzania',
#  u'Kilimazinga',
#  u'Kodera Forest, sites 1-9, Kenya',
#  u'Kopangani (?)',
#  u'Kudang, Gambia',
#  u'Kwale, Kenya',
#  u'Lambwe Valley, Block B, Site 1, Kenya',
#  u'Lambwe Valley, Block B, Site 2, Kenya',
#  u'Lambwe Valley, Block B, Site 3, Kenya',
#  u'Lambwe Valley, Block B, Site 4, Kenya',
#  u'Lambwe Valley, Block B, Site 5, Kenya',
#  u'Lambwe Valley, Kenya',
#  u'Lengobei, Kenya',
#  u"Lengong'u, Kenya",
#  u"Leugong'u, Kenya",
#  u'Luaubwe, Zambia',
#  u'Makut, Sierra Leone',
#  u'Makuti, Zimbabwe',
#  u'Mana Pools, Zimbabwe',
#  u'Marchison Falls, Uganda',
#  u'Monarich (PM)',
#  u'Mukingo, Kenya',
#  u'Mukingo, Nguruman, Kenya',
#  u'Muvumoni (Tanga), Tanzania',
#  u'Mwumoni, Tanzania',
#  u'Narok, Kenya',
#  u'Nguruman (Sampu), Kenya',
#  u'Nguruman, Camp #8, Kenya',
#  u'Nguruman, Camp Site #7B, Kenya',
#  u'Nguruman, Camp Site #8A, Kenya',
#  u'Nguruman, Kattekani, Kenya',
#  u'Nguruman, Kenya',
#  u'Nguruman, Kenya, Camp Site #7, Kenya',
#  u'Nguruman, Kenya, Kalema',
#  u'Nguruman, Kenya, Kalema sites 3,4',
#  u'Nguruman, Kenya, Lengobei sites 1,2',
#  u'Nguruman, Mukingo #1',
#  u'Nguruman, Mukingo #1, Kenya',
#  u'Nguruman, Sampu #1, Kenya',
#  u'Nguruman, Sampu #10, Kenya',
#  u'Nguruman, Sampu #2, Kenya',
#  u'Nguruman, Sampu #3, Kenya',
#  u'Nguruman, Sampu #4, Kenya',
#  u'Nguruman, Sampu, Kenya',
#  u'Nguruman, Sampu, Site #7, Kenya',
#  u'Nguruman, Shompole, Kenya',
#  u'Nyaboro, Site N1',
#  u'Nyaboro, Site N2',
#  u'Nyaboro, Site N3',
#  u'Okame, Uganda',
#  u'Oliobortoto, Kenya',
#  u'Oloibortoto, site 4, Kenya',
#  u'Oloibortoto, sites 1-3, Kenya',
#  u'Parezoologique, Dakar, Senegal',
#  u'Pout, Senegal',
#  u'Rekomitjie, Zimbabwe',
#  u'Rekomityie, Zimbabwe',
#  u'River Keto, Ethiopia',
#  u'Robin Hurt Gate, Makau, Tanzania',
#  u"Ruma Nat'l Park, A10, Kenya",
#  u"Ruma Nat'l Park, Block A, Site 10, Kenya",
#  u"Ruma Nat'l Park, Block A, Site 11, Kenya",
#  u"Ruma Nat'l Park, Block A, Site 17, Kenya",
#  u"Ruma Nat'l Park, Block A, Site 6, Kenya",
#  u"Ruma Nat'l Park, Block A, Site AN, Kenya",
#  u"Ruma Nat'l Park, Block B, Site BN1, Kenya",
#  u"Ruma Nat'l Park, Block B, Site BN2, Kenya",
#  u"Ruma Nat'l Park, Block B, Site BN3, Kenya",
#  u"Ruma Nat'l Park, Block B, Site BN4, Kenya",
#  u"Ruma Nat'l Park, Block B, Site BN5, Kenya",
#  u"Ruma Nat'l Park, Block C, Site C2, Kenya",
#  u"Ruma Nat'l Park, Block C, Site CN1, Kenya",
#  u'Sampu Camp, Nguruman, Kenya',
#  u'Sebikotane, Senegal',
#  u'Serengeti, Tanzania',
#  u'Shimba Hills, Kenya',
#  u'Shompole, Kenya',
#  u'Tanga, Tanzania',
#  u'Tarangire South (Chubi area), Tanzania',
#  u'Tarangire, Sangaiwe, Tanzania',
#  u'Tsavo West, Kenya',
#  u'Uganda',
#  u'Zambia',
#  u'cAG (?)'}

# %%
ng_mask1 = table.Village.apply(lambda x: "ngur" in x.lower())
ng_mask2 = table.Village.apply(lambda x: "oliobortoto" in x.lower())
ng_mask3 = table.Village.apply(lambda x: "lengong" in x.lower())

# %%
True + False
# Out:
# 1

# %%
ng_mask = ng_mask1 | ng_mask2 | ng_mask3

# %%
ng_mask.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Village, dtype: bool

# %%
sum(ng_mask)
# Out:
# 1438

# %%
ng_table = table[ng_mask].dropna(axis=1, how="all")
ng_table.head()
# Out:
#     Lab_Source                     Village Trap_No Date Species  Sex  \
# 121    EPH -80  Nguruman, Kattekani, Kenya       0  NaN      Gp  NaN
# 122    EPH -80  Nguruman, Kattekani, Kenya       0  NaN      Gp  NaN
# 123    EPH -80  Nguruman, Kattekani, Kenya       0  NaN      Gp  NaN
# 124    EPH -80  Nguruman, Kattekani, Kenya       0  NaN      Gp  NaN
# 125    EPH -80  Nguruman, Kattekani, Kenya       0  NaN      Gp  NaN
#
#     Fly_Number  sal_gland Kept_in Comment Tube_or_box Tissue Derivative  \
# 121          1          0    Unk.     NaN         box    NaN       gDNA
# 122          2          0    Unk.     NaN         box    NaN       gDNA
# 123          3          0    Unk.     NaN         box    NaN       gDNA
# 124          4          0    Unk.     NaN         box    NaN       gDNA
# 125          5          0    Unk.     NaN         box    NaN       gDNA
#
#      Box_number_id
# 121              3
# 122              3
# 123              3
# 124              3
# 125              3

# %%
set(ng_table.Village.unique())
# Out:
# {u"Lengong'u, Kenya",
#  u'Mukingo, Nguruman, Kenya',
#  u'Nguruman (Sampu), Kenya',
#  u'Nguruman, Camp #8, Kenya',
#  u'Nguruman, Camp Site #7B, Kenya',
#  u'Nguruman, Camp Site #8A, Kenya',
#  u'Nguruman, Kattekani, Kenya',
#  u'Nguruman, Kenya',
#  u'Nguruman, Kenya, Camp Site #7, Kenya',
#  u'Nguruman, Kenya, Kalema',
#  u'Nguruman, Kenya, Kalema sites 3,4',
#  u'Nguruman, Kenya, Lengobei sites 1,2',
#  u'Nguruman, Mukingo #1',
#  u'Nguruman, Mukingo #1, Kenya',
#  u'Nguruman, Sampu #1, Kenya',
#  u'Nguruman, Sampu #10, Kenya',
#  u'Nguruman, Sampu #2, Kenya',
#  u'Nguruman, Sampu #3, Kenya',
#  u'Nguruman, Sampu #4, Kenya',
#  u'Nguruman, Sampu, Kenya',
#  u'Nguruman, Sampu, Site #7, Kenya',
#  u'Nguruman, Shompole, Kenya',
#  u'Oliobortoto, Kenya',
#  u'Sampu Camp, Nguruman, Kenya'}

# %%
ng_not_dna = ng_table.query("Derivative != 'gDNA'")

# %% [markdown]
# ## How many entries are not labeled as "gDNA"

# %%
len(ng_not_dna)
# Out:
# 77

# %% [markdown]
# ## Which boxes have entries not labeled as "gDNA"

# %%
ng_not_dna.Box_number_id.unique()
# Out:
# array([ 43.,  45.])

# %%
ng_not_dna
# Out:
#                     Lab_Source          Village Trap_No     Date Species  \
# 1912  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1913  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1914  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1915  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1916  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1917  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1918  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1919  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1920  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1921  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1922  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1923  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1924  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1925  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1926  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1927  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1928  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1929  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1930  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1931  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1932  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1933  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1934  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1935  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1936  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1937  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1938  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1939  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1940  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1941  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# ...                        ...              ...     ...      ...     ...
# 1959  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1960  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1961  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1962  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1963  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1964  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1965  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1966  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1967  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1968  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1969  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1970  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1971  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1972  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1973  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1974  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1975  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1976  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1977  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1978  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1979  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1980  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1981  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1982  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 1983  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 2025  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 2026  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 2027  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 2028  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
# 2029  Cold Room Samples (156b)  Nguruman, Kenya       0  2009-11      Gp
#
#         Sex Fly_Number  sal_gland Kept_in             Comment Tube_or_box  \
# 1912      M    NG09001          0    Unk.    Just leg samples         box
# 1913      M    NG09002          0    Unk.    Just leg samples         box
# 1914      M    NG09003          0    Unk.    Just leg samples         box
# 1915      M    NG09004          0    Unk.    Just leg samples         box
# 1916      F    NG09005          0    Unk.    Just leg samples         box
# 1917      F    NG09006          0    Unk.    Just leg samples         box
# 1918      F    NG09007          0    Unk.    Just leg samples         box
# 1919      F    NG09008          0    Unk.    Just leg samples         box
# 1920      F    NG09009          0    Unk.    Just leg samples         box
# 1921      F    NG09010          0    Unk.    Just leg samples         box
# 1922      F    NG09011          0    Unk.    Just leg samples         box
# 1923      F    NG09012          0    Unk.    Just leg samples         box
# 1924      F    NG09013          0    Unk.    Just leg samples         box
# 1925      F    NG09014          0    Unk.    Just leg samples         box
# 1926      F    NG09015          0    Unk.    Just leg samples         box
# 1927      F    NG09016          0    Unk.    Just leg samples         box
# 1928      F    NG09017          0    Unk.    Just leg samples         box
# 1929      F    NG09018          0    Unk.    Just leg samples         box
# 1930      F    NG09019          0    Unk.    Just leg samples         box
# 1931      F    NG09020          0    Unk.    Just leg samples         box
# 1932      F    NG09021          0    Unk.    Just leg samples         box
# 1933      F    NG09022          0    Unk.    Just leg samples         box
# 1934      F    NG09023          0    Unk.    Just leg samples         box
# 1935      F    NG09024          0    Unk.    Just leg samples         box
# 1936      F    NG09025          0    Unk.    Just leg samples         box
# 1937      M    NG09026          0    Unk.    Just leg samples         box
# 1938      F    NG09027          0    Unk.    Just leg samples         box
# 1939      F    NG09028          0    Unk.    Just leg samples         box
# 1940      F    NG09029          0    Unk.    Just leg samples         box
# 1941      F    NG09030          0    Unk.    Just leg samples         box
# ...     ...        ...        ...     ...                 ...         ...
# 1959      F    NG09048          0    Unk.    Just leg samples         box
# 1960      F    NG09049          0    Unk.    Just leg samples         box
# 1961      F    NG09050          0    Unk.    Just leg samples         box
# 1962      F    NG09051          0    Unk.    Just leg samples         box
# 1963      F    NG09052          0    Unk.    Just leg samples         box
# 1964      F    NG09053          0    Unk.    Just leg samples         box
# 1965      F    NG09054          0    Unk.    Just leg samples         box
# 1966      F    NG09055          0    Unk.    Just leg samples         box
# 1967      F    NG09056          0    Unk.    Just leg samples         box
# 1968      F    NG09057          0    Unk.    Just leg samples         box
# 1969      F    NG09058          0    Unk.    Just leg samples         box
# 1970      F    NG09059          0    Unk.    Just leg samples         box
# 1971      M    NG09060          0    Unk.    Just leg samples         box
# 1972      F    NG09061          0    Unk.    Just leg samples         box
# 1973      F    NG09062          0    Unk.    Just leg samples         box
# 1974      F    NG09063          0    Unk.    Just leg samples         box
# 1975      F    NG09064          0    Unk.    Just leg samples         box
# 1976  M (?)    NG09065          0    Unk.    Just leg samples         box
# 1977      F    NG09066          0    Unk.    Just leg samples         box
# 1978      F    NG09067          0    Unk.    Just leg samples         box
# 1979      F    NG09068          0    Unk.    Just leg samples         box
# 1980      F    NG09069          0    Unk.    Just leg samples         box
# 1981      F    NG09070          0    Unk.    Just leg samples         box
# 1982      F    NG09071          0    Unk.    Just leg samples         box
# 1983      F    NG09072          0    Unk.    Just leg samples         box
# 2025      F    NG09073          0    Unk.  Head, thorax, legs         box
# 2026      F    NG09074          0    Unk.  Head, thorax, legs         box
# 2027      M    NG09075          0    Unk.  Head, thorax, legs         box
# 2028      F    NG09076          0    Unk.  Head, thorax, legs         box
# 2029      M    NG09077          0    Unk.  Head, thorax, legs         box
#
#                   Tissue Derivative  Box_number_id
# 1912                legs        NaN             43
# 1913                legs        NaN             43
# 1914                legs        NaN             43
# 1915                legs        NaN             43
# 1916                legs        NaN             43
# 1917                legs        NaN             43
# 1918                legs        NaN             43
# 1919                legs        NaN             43
# 1920                legs        NaN             43
# 1921                legs        NaN             43
# 1922                legs        NaN             43
# 1923                legs        NaN             43
# 1924                legs        NaN             43
# 1925                legs        NaN             43
# 1926                legs        NaN             43
# 1927                legs        NaN             43
# 1928                legs        NaN             43
# 1929                legs        NaN             43
# 1930                legs        NaN             43
# 1931                legs        NaN             43
# 1932                legs        NaN             43
# 1933                legs        NaN             43
# 1934                legs        NaN             43
# 1935                legs        NaN             43
# 1936                legs        NaN             43
# 1937                legs        NaN             43
# 1938                legs        NaN             43
# 1939                legs        NaN             43
# 1940                legs        NaN             43
# 1941                legs        NaN             43
# ...                  ...        ...            ...
# 1959                legs        NaN             43
# 1960                legs        NaN             43
# 1961                legs        NaN             43
# 1962                legs        NaN             43
# 1963                legs        NaN             43
# 1964                legs        NaN             43
# 1965                legs        NaN             43
# 1966                legs        NaN             43
# 1967                legs        NaN             43
# 1968                legs        NaN             43
# 1969                legs        NaN             43
# 1970                legs        NaN             43
# 1971                legs        NaN             43
# 1972                legs        NaN             43
# 1973                legs        NaN             43
# 1974                legs        NaN             43
# 1975                legs        NaN             43
# 1976                legs        NaN             43
# 1977                legs        NaN             43
# 1978                legs        NaN             43
# 1979                legs        NaN             43
# 1980                legs        NaN             43
# 1981                legs        NaN             43
# 1982                legs        NaN             43
# 1983                legs        NaN             43
# 2025  head, thorax, legs        NaN             45
# 2026  head, thorax, legs        NaN             45
# 2027  head, thorax, legs        NaN             45
# 2028  head, thorax, legs        NaN             45
# 2029  head, thorax, legs        NaN             45
#
# [77 rows x 14 columns]

# %% [markdown]
# ### Only have location information for extracted material?
#
# - Boxes 43 and 45 have un extracted material but the finest scale location seems to be "Nguruman"

# %% [markdown]
# ## Get extracted material then

# %%
for site in ng_table.Village.unique():
    print site
# Out:
# Nguruman, Kattekani, Kenya
# Sampu Camp, Nguruman, Kenya
# Mukingo, Nguruman, Kenya
# Nguruman, Kenya
# Nguruman, Camp #8, Kenya
# Nguruman, Sampu, Site #7, Kenya
# Nguruman (Sampu), Kenya
# Nguruman, Sampu #3, Kenya
# Nguruman, Mukingo #1, Kenya
# Nguruman, Sampu #1, Kenya
# Nguruman, Sampu #4, Kenya
# Oliobortoto, Kenya
# Nguruman, Sampu, Kenya
# Nguruman, Shompole, Kenya
# Lengong'u, Kenya
# Nguruman, Kenya, Lengobei sites 1,2
# Nguruman, Kenya, Kalema sites 3,4
# Nguruman, Kenya, Kalema
# Nguruman, Sampu #2, Kenya
# Nguruman, Sampu #10, Kenya
# Nguruman, Mukingo #1
# Nguruman, Kenya, Camp Site #7, Kenya
# Nguruman, Camp Site #7B, Kenya
# Nguruman, Camp Site #8A, Kenya

# %%
make_list = lambda x: ", ".join(set(x))

# %%
# ng_table.pivot_table(values=None, 
#                      index="Village", 
#                      columns=None, 
#                      aggfunc=[make_list,len], 
#                      fill_value=None, margins=False, dropna=True)

# %%
sorted(list(ng_table.Box_number_id.unique()))
# Out:
# [3.0,
#  10.0,
#  11.0,
#  12.0,
#  13.0,
#  14.0,
#  15.0,
#  17.0,
#  20.0,
#  24.0,
#  25.0,
#  27.0,
#  28.0,
#  30.0,
#  32.0,
#  33.0,
#  34.0,
#  39.0,
#  41.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  53.0,
#  54.0,
#  58.0,
#  62.0,
#  79.0,
#  83.0]

# %%
# ng_table.to_excel("/home/gus/Documents/YalePostDoc/project_stuff/G_pallidipes_kenya/Michael/Krafsur/nguruman.xls")
